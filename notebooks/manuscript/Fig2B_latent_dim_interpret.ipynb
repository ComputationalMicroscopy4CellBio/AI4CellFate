# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
from pathlib import Path
import glob
import re

# Set up plotting parameters
plt.rcParams['font.family'] = 'Arial'
plt.rcParams['font.size'] = 12

print("🔬 SI Latent Dimension Study - Interpretability Analysis")
print("="*60)
# Out:
# 🔬 SI Latent Dimension Study - Interpretability Analysis
# ============================================================

# %%
def load_latent_dim_metrics(results_dir, latent_dims, seeds):
    """
    Load metrics for all latent dimensions and seeds from the latent dimension study.
    
    Args:
        results_dir: Path to results directory
        latent_dims: List of latent dimensions to analyze
        seeds: List of seeds to analyze
    
    Returns:
        dict: Nested dictionary with metrics for each latent dimension and seed
    """
    
    all_metrics = {}
    
    for latent_dim in latent_dims:
        print(f"\n📐 Processing Latent Dimension: {latent_dim}")
        
        dim_metrics = {
            'accuracy': [],
            'precision': [],
            'correlation': [],
            'covariance': [],
            'kl_divergence': [],
            'seeds_found': []
        }
        
        for seed in seeds:
            # Construct folder name based on your naming convention
            folder_name = f"s1_ep100_lr5_la1_seed{seed}_ldim{latent_dim}_s2_lr6_la2_lc1_lcon0.2"
            folder_path = results_dir / folder_name
            
            if folder_path.exists():
                print(f"   🌱 Seed {seed}: ✅ Found")
                dim_metrics['seeds_found'].append(seed)
                
                try:
                    # Load confusion matrix for accuracy and precision
                    cm_files = list(folder_path.glob("confusion_matrix_values_epoch_*.npy"))
                    if cm_files:
                        latest_cm = max(cm_files, key=lambda x: int(x.stem.split('_')[-1]))
                        conf_matrix = np.load(latest_cm)
                        print(latest_cm)
                        # Calculate accuracy (mean diagonal)
                        accuracy = np.mean(np.diag(conf_matrix))
                        dim_metrics['accuracy'].append(accuracy)
                        
                        # Calculate precision (class 0)
                        if conf_matrix[0,0] + conf_matrix[1,0] > 0:
                            precision = conf_matrix[0,0] / (conf_matrix[0,0] + conf_matrix[1,0])
                            dim_metrics['precision'].append(precision)
                        
                        print(f"        - Accuracy: {accuracy:.4f}, Precision: {precision:.4f}")
                    
                    # Load correlation matrix
                    corr_files = sorted(folder_path.glob("latent_correlation_matrix_epoch_*.npy"))
                    if corr_files:
                        latest_corr = corr_files[-1] #max(corr_files, key=lambda x: int(x.stem.split('_')[-1]))
                        corr_matrix = np.load(latest_corr)
                     
                        # Calculate highest absolute off-diagonal correlation
                        if corr_matrix.shape[0] > 1:
                            off_diag_mask = ~np.eye(corr_matrix.shape[0], dtype=bool)
                            max_corr = np.max(np.abs(corr_matrix[off_diag_mask]))
                            dim_metrics['correlation'].append(max_corr)
                            print(f"        - Correlation (max): {max_corr:.4f}")
                    
                    # Load covariance matrix
                    cov_files = sorted(folder_path.glob("latent_covariance_matrix_epoch_*.npy"))
                    if cov_files:
                        latest_cov = cov_files[-1]
                        cov_matrix = np.load(latest_cov)
                        
                        # Calculate absolute sum of off-diagonal covariance
                        if cov_matrix.shape[0] > 1:
                            off_diag_mask = ~np.eye(cov_matrix.shape[0], dtype=bool)
                            sum_cov = np.abs(np.sum(cov_matrix[off_diag_mask]))
                            dim_metrics['covariance'].append(sum_cov)
                            print(f"        - Covariance (abs sum): {sum_cov:.4f}")
                    
                    # Load KL divergences
                    kl_files = list(folder_path.glob("kl_divergences_epoch_*.npy"))
                    if kl_files:
                        latest_kl = max(kl_files, key=lambda x: int(x.stem.split('_')[-1]))
                        kl_divergences = np.load(latest_kl)
                        avg_kl = np.mean(kl_divergences)
                        dim_metrics['kl_divergence'].append(avg_kl)
                        print(f"        - KL Divergence: {avg_kl:.4f}")
                        
                except Exception as e:
                    print(f"        ❌ Error loading metrics: {e}")
            else:
                print(f"   🌱 Seed {seed}: ❌ Missing")
        
        all_metrics[latent_dim] = dim_metrics
        n_seeds = len(dim_metrics['seeds_found'])
        print(f"   📊 Summary: {n_seeds}/{len(seeds)} seeds found")
    
    return all_metrics

# Define parameters
results_dir = Path("/Volumes/InesSeagate/PhotoFate/16Feb/latent_dim_study")
latent_dims = [2, 3, 4, 5, 6, 7, 8, 9, 10, 13, 20, 30, 50] #, 2, 3, 4, 5, 6, 7, 8, 9, 10, 13, 20, 30, 50, 100
seeds = [42, 43, 44] #48

print(f"📂 Loading metrics from: {results_dir}")
print(f"🎯 Target latent dimensions: {latent_dims}")
print(f"🌱 Seeds to analyze: {seeds}")

# Load all metrics
all_metrics = load_latent_dim_metrics(results_dir, latent_dims, seeds)
# Out:
# 📂 Loading metrics from: /Volumes/InesSeagate/PhotoFate/16Feb/latent_dim_study
# 🎯 Target latent dimensions: [2, 3, 4, 5, 6, 7, 8, 9, 10, 13, 20, 30, 50]
# 🌱 Seeds to analyze: [42, 43, 44]
#
# 📐 Processing Latent Dimension: 2
#    🌱 Seed 42: ✅ Found
# /Volumes/InesSeagate/PhotoFate/16Feb/latent_dim_study/s1_ep100_lr5_la1_seed42_ldim2_s2_lr6_la2_lc1_lcon0.2/confusion_matrix_values_epoch_90.npy
#         - Accuracy: 0.8081, Precision: 0.8675
#         - Correlation (max): 0.1121
#         - Covariance (abs sum): 0.3303
#         - KL Divergence: 0.2167
#    🌱 Seed 43: ✅ Found
# /Volumes/InesSeagate/PhotoFate/16Feb/latent_dim_study/s1_ep100_lr5_la1_seed43_ldim2_s2_lr6_la2_lc1_lcon0.2/confusion_matrix_values_epoch_92.npy
#         - Accuracy: 0.8359, Precision: 0.9290
#         - Correlation (max): 0.0682
#         - Covariance (abs sum): 0.1926
#         - KL Divergence: 0.1487
#    🌱 Seed 44: ✅ Found
# /Volumes/InesSeagate/PhotoFate/16Feb/latent_dim_study/s1_ep100_lr5_la1_seed44_ldim2_s2_lr6_la2_lc1_lcon0.2/confusion_matrix_values_epoch_93.npy
#         - Accuracy: 0.7424, Precision: 0.7105
#         - Correlation (max): 0.0642
#         - Covariance (abs sum): 0.2012
#         - KL Divergence: 0.1869
#    📊 Summary: 3/3 seeds found
#
# 📐 Processing Latent Dimension: 3
#    🌱 Seed 42: ✅ Found
# /Volumes/InesSeagate/PhotoFate/16Feb/latent_dim_study/s1_ep100_lr5_la1_seed42_ldim3_s2_lr6_la2_lc1_lcon0.2/confusion_matrix_values_epoch_70.npy
#         - Accuracy: 0.8258, Precision: 0.8308
#         - Correlation (max): 0.1807
#         - Covariance (abs sum): 0.4119
#         - KL Divergence: 0.2887
#    🌱 Seed 43: ✅ Found
# /Volumes/InesSeagate/PhotoFate/16Feb/latent_dim_study/s1_ep100_lr5_la1_seed43_ldim3_s2_lr6_la2_lc1_lcon0.2/confusion_matrix_values_epoch_86.npy
#         - Accuracy: 0.7146, Precision: 0.6778
#         - Correlation (max): 0.1309
#         - Covariance (abs sum): 0.3049
#         - KL Divergence: 0.1961
#    🌱 Seed 44: ✅ Found
# /Volumes/InesSeagate/PhotoFate/16Feb/latent_dim_study/s1_ep100_lr5_la1_seed44_ldim3_s2_lr6_la2_lc1_lcon0.2/confusion_matrix_values_epoch_99.npy
#         - Accuracy: 0.7980, Precision: 0.7864
#         - Correlation (max): 0.1864
#         - Covariance (abs sum): 1.4886
#         - KL Divergence: 0.1847
#    📊 Summary: 3/3 seeds found
#
# 📐 Processing Latent Dimension: 4
#    🌱 Seed 42: ✅ Found
# /Volumes/InesSeagate/PhotoFate/16Feb/latent_dim_study/s1_ep100_lr5_la1_seed42_ldim4_s2_lr6_la2_lc1_lcon0.2/confusion_matrix_values_epoch_91.npy
#         - Accuracy: 0.6263, Precision: 0.7660
#         - Correlation (max): 0.2290
#         - Covariance (abs sum): 0.5094
#         - KL Divergence: 0.2415
#    🌱 Seed 43: ✅ Found
# /Volumes/InesSeagate/PhotoFate/16Feb/latent_dim_study/s1_ep100_lr5_la1_seed43_ldim4_s2_lr6_la2_lc1_lcon0.2/confusion_matrix_values_epoch_90.npy
#         - Accuracy: 0.6692, Precision: 0.6516
#         - Correlation (max): 0.1973
#         - Covariance (abs sum): 0.3077
#         - KL Divergence: 0.2375
#    🌱 Seed 44: ✅ Found
# /Volumes/InesSeagate/PhotoFate/16Feb/latent_dim_study/s1_ep100_lr5_la1_seed44_ldim4_s2_lr6_la2_lc1_lcon0.2/confusion_matrix_values_epoch_94.npy
#         - Accuracy: 0.7247, Precision: 0.7236
#         - Correlation (max): 0.1246
#         - Covariance (abs sum): 0.1363
#         - KL Divergence: 0.2137
#    📊 Summary: 3/3 seeds found
#
# 📐 Processing Latent Dimension: 5
#    🌱 Seed 42: ✅ Found
# /Volumes/InesSeagate/PhotoFate/16Feb/latent_dim_study/s1_ep100_lr5_la1_seed42_ldim5_s2_lr6_la2_lc1_lcon0.2/confusion_matrix_values_epoch_98.npy
#         - Accuracy: 0.6237, Precision: 0.6207
#         - Correlation (max): 0.2158
#         - Covariance (abs sum): 0.1397
#         - KL Divergence: 0.2176
#    🌱 Seed 43: ✅ Found
# /Volumes/InesSeagate/PhotoFate/16Feb/latent_dim_study/s1_ep100_lr5_la1_seed43_ldim5_s2_lr6_la2_lc1_lcon0.2/confusion_matrix_values_epoch_77.npy
#         - Accuracy: 0.7146, Precision: 0.6778
#         - Correlation (max): 0.2070
#         - Covariance (abs sum): 0.0218
#         - KL Divergence: 0.1980
#    🌱 Seed 44: ✅ Found
# /Volumes/InesSeagate/PhotoFate/16Feb/latent_dim_study/s1_ep100_lr5_la1_seed44_ldim5_s2_lr6_la2_lc1_lcon0.2/confusion_matrix_values_epoch_89.npy
#         - Accuracy: 0.7879, Precision: 0.7317
#         - Correlation (max): 0.1181
#         - Covariance (abs sum): 0.4905
#         - KL Divergence: 0.2017
#    📊 Summary: 3/3 seeds found
#
# 📐 Processing Latent Dimension: 6
#    🌱 Seed 42: ✅ Found
# /Volumes/InesSeagate/PhotoFate/16Feb/latent_dim_study/s1_ep100_lr5_la1_seed42_ldim6_s2_lr6_la2_lc1_lcon0.2/confusion_matrix_values_epoch_91.npy
#         - Accuracy: 0.7348, Precision: 0.7925
#         - Correlation (max): 0.3476
#         - Covariance (abs sum): 1.7246
#         - KL Divergence: 0.2499
#    🌱 Seed 43: ✅ Found
# /Volumes/InesSeagate/PhotoFate/16Feb/latent_dim_study/s1_ep100_lr5_la1_seed43_ldim6_s2_lr6_la2_lc1_lcon0.2/confusion_matrix_values_epoch_91.npy
#         - Accuracy: 0.6338, Precision: 0.6626
#         - Correlation (max): 0.3578
#         - Covariance (abs sum): 3.3431
#         - KL Divergence: 0.2723
#    🌱 Seed 44: ✅ Found
# /Volumes/InesSeagate/PhotoFate/16Feb/latent_dim_study/s1_ep100_lr5_la1_seed44_ldim6_s2_lr6_la2_lc1_lcon0.2/confusion_matrix_values_epoch_88.npy
#         - Accuracy: 0.7146, Precision: 0.6778
#         - Correlation (max): 0.1953
#         - Covariance (abs sum): 0.7024
#         - KL Divergence: 0.1801
#    📊 Summary: 3/3 seeds found
#
# 📐 Processing Latent Dimension: 7
#    🌱 Seed 42: ✅ Found
# /Volumes/InesSeagate/PhotoFate/16Feb/latent_dim_study/s1_ep100_lr5_la1_seed42_ldim7_s2_lr6_la2_lc1_lcon0.2/confusion_matrix_values_epoch_90.npy
#         - Accuracy: 0.7323, Precision: 0.6716
#         - Correlation (max): 0.2236
#         - Covariance (abs sum): 1.3637
#         - KL Divergence: 0.1906
#    🌱 Seed 43: ✅ Found
# /Volumes/InesSeagate/PhotoFate/16Feb/latent_dim_study/s1_ep100_lr5_la1_seed43_ldim7_s2_lr6_la2_lc1_lcon0.2/confusion_matrix_values_epoch_91.npy
#         - Accuracy: 0.7146, Precision: 0.6778
#         - Correlation (max): 0.3216
#         - Covariance (abs sum): 2.2126
#         - KL Divergence: 0.1845
#    🌱 Seed 44: ✅ Found
# /Volumes/InesSeagate/PhotoFate/16Feb/latent_dim_study/s1_ep100_lr5_la1_seed44_ldim7_s2_lr6_la2_lc1_lcon0.2/confusion_matrix_values_epoch_93.npy
#         - Accuracy: 0.7424, Precision: 0.7105
#         - Correlation (max): 0.2141
#         - Covariance (abs sum): 1.7708
#         - KL Divergence: 0.2129
#    📊 Summary: 3/3 seeds found
#
# 📐 Processing Latent Dimension: 8
#    🌱 Seed 42: ✅ Found
# /Volumes/InesSeagate/PhotoFate/16Feb/latent_dim_study/s1_ep100_lr5_la1_seed42_ldim8_s2_lr6_la2_lc1_lcon0.2/confusion_matrix_values_epoch_90.npy
#         - Accuracy: 0.7146, Precision: 0.6778
#         - Correlation (max): 0.2763
#         - Covariance (abs sum): 1.6239
#         - KL Divergence: 0.2223
#    🌱 Seed 43: ✅ Found
# /Volumes/InesSeagate/PhotoFate/16Feb/latent_dim_study/s1_ep100_lr5_la1_seed43_ldim8_s2_lr6_la2_lc1_lcon0.2/confusion_matrix_values_epoch_87.npy
#         - Accuracy: 0.7424, Precision: 0.7105
#         - Correlation (max): 0.3803
#         - Covariance (abs sum): 2.6140
#         - KL Divergence: 0.1723
#    🌱 Seed 44: ✅ Found
# /Volumes/InesSeagate/PhotoFate/16Feb/latent_dim_study/s1_ep100_lr5_la1_seed44_ldim8_s2_lr6_la2_lc1_lcon0.2/confusion_matrix_values_epoch_92.npy
#         - Accuracy: 0.8258, Precision: 0.8308
#         - Correlation (max): 0.2593
#         - Covariance (abs sum): 1.9592
#         - KL Divergence: 0.2162
#    📊 Summary: 3/3 seeds found
#
# 📐 Processing Latent Dimension: 9
#    🌱 Seed 42: ✅ Found
# /Volumes/InesSeagate/PhotoFate/16Feb/latent_dim_study/s1_ep100_lr5_la1_seed42_ldim9_s2_lr6_la2_lc1_lcon0.2/confusion_matrix_values_epoch_90.npy
#         - Accuracy: 0.7601, Precision: 0.7004
#         - Correlation (max): 0.3233
#         - Covariance (abs sum): 0.5680
#         - KL Divergence: 0.1709
#    🌱 Seed 43: ✅ Found
# /Volumes/InesSeagate/PhotoFate/16Feb/latent_dim_study/s1_ep100_lr5_la1_seed43_ldim9_s2_lr6_la2_lc1_lcon0.2/confusion_matrix_values_epoch_87.npy
#         - Accuracy: 0.6970, Precision: 0.6857
#         - Correlation (max): 0.4746
#         - Covariance (abs sum): 0.8450
#         - KL Divergence: 0.1900
#    🌱 Seed 44: ✅ Found
# /Volumes/InesSeagate/PhotoFate/16Feb/latent_dim_study/s1_ep100_lr5_la1_seed44_ldim9_s2_lr6_la2_lc1_lcon0.2/confusion_matrix_values_epoch_81.npy
#         - Accuracy: 0.7626, Precision: 0.8514
#         - Correlation (max): 0.3661
#         - Covariance (abs sum): 0.1056
#         - KL Divergence: 0.2457
#    📊 Summary: 3/3 seeds found
#
# 📐 Processing Latent Dimension: 10
#    🌱 Seed 42: ✅ Found
# /Volumes/InesSeagate/PhotoFate/16Feb/latent_dim_study/s1_ep100_lr5_la1_seed42_ldim10_s2_lr6_la2_lc1_lcon0.2/confusion_matrix_values_epoch_90.npy
#         - Accuracy: 0.7424, Precision: 0.7105
#         - Correlation (max): 0.3098
#         - Covariance (abs sum): 2.2696
#         - KL Divergence: 0.1906
#    🌱 Seed 43: ✅ Found
# /Volumes/InesSeagate/PhotoFate/16Feb/latent_dim_study/s1_ep100_lr5_la1_seed43_ldim10_s2_lr6_la2_lc1_lcon0.2/confusion_matrix_values_epoch_84.npy
#         - Accuracy: 0.7980, Precision: 0.7864
#         - Correlation (max): 0.3030
#         - Covariance (abs sum): 2.6863
#         - KL Divergence: 0.1695
#    🌱 Seed 44: ✅ Found
# /Volumes/InesSeagate/PhotoFate/16Feb/latent_dim_study/s1_ep100_lr5_la1_seed44_ldim10_s2_lr6_la2_lc1_lcon0.2/confusion_matrix_values_epoch_90.npy
#         - Accuracy: 0.6970, Precision: 0.6857
#         - Correlation (max): 0.3726
#         - Covariance (abs sum): 2.9751
#         - KL Divergence: 0.2134
#    📊 Summary: 3/3 seeds found
#
# 📐 Processing Latent Dimension: 13
#    🌱 Seed 42: ✅ Found
# /Volumes/InesSeagate/PhotoFate/16Feb/latent_dim_study/s1_ep100_lr5_la1_seed42_ldim13_s2_lr6_la2_lc1_lcon0.2/confusion_matrix_values_epoch_90.npy
#         - Accuracy: 0.7071, Precision: 0.7412
#         - Correlation (max): 0.3205
#         - Covariance (abs sum): 1.9107
#         - KL Divergence: 0.1426
#    🌱 Seed 43: ✅ Found
# /Volumes/InesSeagate/PhotoFate/16Feb/latent_dim_study/s1_ep100_lr5_la1_seed43_ldim13_s2_lr6_la2_lc1_lcon0.2/confusion_matrix_values_epoch_78.npy
#         - Accuracy: 0.7601, Precision: 0.7004
#         - Correlation (max): 0.3724
#         - Covariance (abs sum): 0.6666
#         - KL Divergence: 0.1707
#    🌱 Seed 44: ✅ Found
# /Volumes/InesSeagate/PhotoFate/16Feb/latent_dim_study/s1_ep100_lr5_la1_seed44_ldim13_s2_lr6_la2_lc1_lcon0.2/confusion_matrix_values_epoch_89.npy
#         - Accuracy: 0.7601, Precision: 0.7004
#         - Correlation (max): 0.3825
#         - Covariance (abs sum): 2.0639
#         - KL Divergence: 0.1923
#    📊 Summary: 3/3 seeds found
#
# 📐 Processing Latent Dimension: 20
#    🌱 Seed 42: ✅ Found
# /Volumes/InesSeagate/PhotoFate/16Feb/latent_dim_study/s1_ep100_lr5_la1_seed42_ldim20_s2_lr6_la2_lc1_lcon0.2/confusion_matrix_values_epoch_89.npy
#         - Accuracy: 0.7803, Precision: 0.8136
#         - Correlation (max): 0.5333
#         - Covariance (abs sum): 0.3941
#         - KL Divergence: 0.1443
#    🌱 Seed 43: ✅ Found
# /Volumes/InesSeagate/PhotoFate/16Feb/latent_dim_study/s1_ep100_lr5_la1_seed43_ldim20_s2_lr6_la2_lc1_lcon0.2/confusion_matrix_values_epoch_88.npy
#         - Accuracy: 0.6793, Precision: 0.6961
#         - Correlation (max): 0.5977
#         - Covariance (abs sum): 1.7337
#         - KL Divergence: 0.1418
#    🌱 Seed 44: ✅ Found
# /Volumes/InesSeagate/PhotoFate/16Feb/latent_dim_study/s1_ep100_lr5_la1_seed44_ldim20_s2_lr6_la2_lc1_lcon0.2/confusion_matrix_values_epoch_90.npy
#         - Accuracy: 0.7601, Precision: 0.7004
#         - Correlation (max): 0.4803
#         - Covariance (abs sum): 7.2086
#         - KL Divergence: 0.1415
#    📊 Summary: 3/3 seeds found
#
# 📐 Processing Latent Dimension: 30
#    🌱 Seed 42: ✅ Found
# /Volumes/InesSeagate/PhotoFate/16Feb/latent_dim_study/s1_ep100_lr5_la1_seed42_ldim30_s2_lr6_la2_lc1_lcon0.2/confusion_matrix_values_epoch_90.npy
#         - Accuracy: 0.7146, Precision: 0.6778
#         - Correlation (max): 0.5867
#         - Covariance (abs sum): 3.4416
#         - KL Divergence: 0.9930
#    🌱 Seed 43: ✅ Found
# /Volumes/InesSeagate/PhotoFate/16Feb/latent_dim_study/s1_ep100_lr5_la1_seed43_ldim30_s2_lr6_la2_lc1_lcon0.2/confusion_matrix_values_epoch_78.npy
#         - Accuracy: 0.7071, Precision: 0.7412
#         - Correlation (max): 0.5411
#         - Covariance (abs sum): 9.3838
#         - KL Divergence: 0.1465
#    🌱 Seed 44: ✅ Found
# /Volumes/InesSeagate/PhotoFate/16Feb/latent_dim_study/s1_ep100_lr5_la1_seed44_ldim30_s2_lr6_la2_lc1_lcon0.2/confusion_matrix_values_epoch_79.npy
#         - Accuracy: 0.7778, Precision: 0.6923
#         - Correlation (max): 0.6393
#         - Covariance (abs sum): 8.3907
#         - KL Divergence: 1.7170
#    📊 Summary: 3/3 seeds found
#
# 📐 Processing Latent Dimension: 50
#    🌱 Seed 42: ✅ Found
# /Volumes/InesSeagate/PhotoFate/16Feb/latent_dim_study/s1_ep100_lr5_la1_seed42_ldim50_s2_lr6_la2_lc1_lcon0.2/confusion_matrix_values_epoch_86.npy
#         - Accuracy: 0.7323, Precision: 0.6716
#         - Correlation (max): 0.5851
#         - Covariance (abs sum): 5.3329
#         - KL Divergence: 1.2507
#    🌱 Seed 43: ✅ Found
# /Volumes/InesSeagate/PhotoFate/16Feb/latent_dim_study/s1_ep100_lr5_la1_seed43_ldim50_s2_lr6_la2_lc1_lcon0.2/confusion_matrix_values_epoch_87.npy
#         - Accuracy: 0.7525, Precision: 0.7660
#         - Correlation (max): 0.6467
#         - Covariance (abs sum): 18.2334
#         - KL Divergence: 1.7405
#    🌱 Seed 44: ✅ Found
# /Volumes/InesSeagate/PhotoFate/16Feb/latent_dim_study/s1_ep100_lr5_la1_seed44_ldim50_s2_lr6_la2_lc1_lcon0.2/confusion_matrix_values_epoch_87.npy
#         - Accuracy: 0.6970, Precision: 0.6857
#         - Correlation (max): 0.5550
#         - Covariance (abs sum): 2.3708
#         - KL Divergence: 0.8402
#    📊 Summary: 3/3 seeds found

# %%
def calculate_mean_std_metrics(all_metrics, latent_dims):
    """Calculate mean and std for each metric across seeds."""
    
    results = {
        'latent_dims': [],
        'mean_accuracy': [],
        'std_accuracy': [],
        'mean_precision': [],
        'std_precision': [],
        'mean_correlation': [],
        'std_correlation': [],
        'mean_covariance': [],
        'std_covariance': [],
        'mean_kl_divergence': [],
        'std_kl_divergence': []
    }
    
    for latent_dim in latent_dims:
        if latent_dim in all_metrics:
            metrics = all_metrics[latent_dim]
            
            # Only include dimensions with at least some data
            if len(metrics['seeds_found']) > 0:
                results['latent_dims'].append(latent_dim)
                
                # Calculate means and stds for each metric
                for metric_name in ['accuracy', 'precision', 'correlation', 'covariance', 'kl_divergence']:
                    values = metrics[metric_name]
                    if values:
                        mean_val = np.mean(values)
                        std_val = np.std(values, ddof=1) if len(values) > 1 else 0
                    else:
                        mean_val = np.nan
                        std_val = np.nan
                    
                    results[f'mean_{metric_name}'].append(mean_val)
                    results[f'std_{metric_name}'].append(std_val)
    
    return results

# Calculate summary statistics
print("\n📊 Calculating mean and standard deviation across seeds...")
summary_stats = calculate_mean_std_metrics(all_metrics, latent_dims)

# Display summary
print(f"\n✅ Successfully processed {len(summary_stats['latent_dims'])} latent dimensions:")
for i, ldim in enumerate(summary_stats['latent_dims']):
    acc = summary_stats['mean_accuracy'][i]
    prec = summary_stats['mean_precision'][i]
    corr = summary_stats['mean_correlation'][i]
    print(f"  - Dim {ldim}: Accuracy={acc:.3f}, Precision={prec:.3f}, Correlation={corr:.3f}")

print("\n🎯 Ready to create plots!")
# Out:
# 📊 Calculating mean and standard deviation across seeds...
#
# ✅ Successfully processed 13 latent dimensions:
#   - Dim 2: Accuracy=0.795, Precision=0.836, Correlation=0.081
#   - Dim 3: Accuracy=0.779, Precision=0.765, Correlation=0.166
#   - Dim 4: Accuracy=0.673, Precision=0.714, Correlation=0.184
#   - Dim 5: Accuracy=0.709, Precision=0.677, Correlation=0.180
#   - Dim 6: Accuracy=0.694, Precision=0.711, Correlation=0.300
#   - Dim 7: Accuracy=0.730, Precision=0.687, Correlation=0.253
#   - Dim 8: Accuracy=0.761, Precision=0.740, Correlation=0.305
#   - Dim 9: Accuracy=0.740, Precision=0.746, Correlation=0.388
#   - Dim 10: Accuracy=0.746, Precision=0.728, Correlation=0.328
#   - Dim 13: Accuracy=0.742, Precision=0.714, Correlation=0.358
#   - Dim 20: Accuracy=0.740, Precision=0.737, Correlation=0.537
#   - Dim 30: Accuracy=0.733, Precision=0.704, Correlation=0.589
#   - Dim 50: Accuracy=0.727, Precision=0.708, Correlation=0.596
#
# 🎯 Ready to create plots!

# %%
# PLOT 1: Model Performance - Precision over Latent Dimensions
print("📈 Creating Plot 1: Precision over Latent Dimensions")

plt.figure(figsize=(8, 6))

# Extract data
dims = summary_stats['latent_dims']
mean_precisions = summary_stats['mean_precision']
std_precisions = summary_stats['std_precision']

# Remove any NaN values for plotting
valid_indices = [i for i, (mean, std) in enumerate(zip(mean_precisions, std_precisions)) 
                 if not (np.isnan(mean) or np.isnan(std))]

if valid_indices:
    plot_dims = [dims[i] for i in valid_indices]
    plot_means = [mean_precisions[i] for i in valid_indices]
    plot_stds = [std_precisions[i] for i in valid_indices]
    
    # Precision (orange) - matching your reference style
    plt.plot(plot_dims, plot_means, color='purple', linewidth=2, label='Precision', marker='o', markersize=6)
    plt.fill_between(plot_dims, 
                     np.array(plot_means) - np.array(plot_stds), 
                     np.array(plot_means) + np.array(plot_stds),
                     color='purple', alpha=0.3)
    
    # Formatting to match your reference
    plt.xlabel("Latent Space Dimension", fontsize=16, fontname="Arial")
    plt.ylabel("Precision", fontsize=16, fontname="Arial")
    plt.title("Precision over Latent Dimensions", fontsize=18, fontname="Arial")
    plt.xticks(fontsize=14, fontname="Arial")
    plt.yticks(fontsize=14, fontname="Arial")
    
    # Set reasonable y-axis range
    y_min = 0.0#max(0.1, min(plot_means) - max(plot_stds) - 0.05)
    y_max = 1.1#min(1.0, max(plot_means) + max(plot_stds) + 0.05)
    plt.ylim(y_min, y_max)
    
    plt.grid(True, linestyle="--", alpha=0.6)
    
    # Save the figure
    # plt.savefig("../../results/latent_dim_precision.png", dpi=300, bbox_inches="tight")
    # plt.savefig("../../results/latent_dim_precision.eps", dpi=300, bbox_inches="tight")
    
    plt.show()
    
    print(f"✅ Precision plot saved with {len(plot_dims)} data points")
else:
    print("❌ No valid precision data found for plotting")
# Out:
# 📈 Creating Plot 1: Precision over Latent Dimensions
# ✅ Precision plot saved with 13 data points

# %%
# PLOT 2: Model Performance - Accuracy over Latent Dimensions
print("📈 Creating Plot 2: Accuracy over Latent Dimensions")

plt.figure(figsize=(8, 6))

# Extract data
mean_accuracies = summary_stats['mean_accuracy']
std_accuracies = summary_stats['std_accuracy']

# Remove any NaN values for plotting
valid_indices = [i for i, (mean, std) in enumerate(zip(mean_accuracies, std_accuracies)) 
                 if not (np.isnan(mean) or np.isnan(std))]

if valid_indices:
    plot_dims = [dims[i] for i in valid_indices]
    plot_means = [mean_accuracies[i] for i in valid_indices]
    plot_stds = [std_accuracies[i] for i in valid_indices]
    
    # Accuracy (blue) 
    plt.plot(plot_dims, plot_means, color='orange', linewidth=2, label='Accuracy', marker='s', markersize=6)
    plt.fill_between(plot_dims, 
                     np.array(plot_means) - np.array(plot_stds), 
                     np.array(plot_means) + np.array(plot_stds),
                     color='orange', alpha=0.3)
    
    # Formatting
    plt.xlabel("Latent Space Dimension", fontsize=16, fontname="Arial")
    plt.ylabel("Accuracy", fontsize=16, fontname="Arial")
    plt.title("Accuracy over Latent Dimensions", fontsize=18, fontname="Arial")
    plt.xticks(fontsize=14, fontname="Arial")
    plt.yticks(fontsize=14, fontname="Arial")
    
    # Set reasonable y-axis range
    y_min = 0.0#max(0.1, min(plot_means) - max(plot_stds) - 0.05)
    y_max = 1.0#min(1.0, max(plot_means) + max(plot_stds) + 0.05)
    plt.ylim(y_min, y_max)
    
    plt.grid(True, linestyle="--", alpha=0.6)
    
    # Save the figure
    # plt.savefig("../../results/latent_dim_accuracy.png", dpi=300, bbox_inches="tight")
    #plt.savefig("brightfield_latent_dim_accuracy.eps", dpi=300, bbox_inches="tight")
    
    plt.show()
    
    print(f"✅ Accuracy plot saved with {len(plot_dims)} data points")
else:
    print("❌ No valid accuracy data found for plotting")
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# 📈 Creating Plot 2: Accuracy over Latent Dimensions
# ✅ Accuracy plot saved with 13 data points

# %%
# PLOT 3: Feature Correlation over Latent Dimensions
print("📈 Creating Plot 3: Feature Correlation over Latent Dimensions")

plt.figure(figsize=(8, 6))

# Extract data
mean_correlations = summary_stats['mean_correlation']
std_correlations = summary_stats['std_correlation']

# Remove any NaN values for plotting
valid_indices = [i for i, (mean, std) in enumerate(zip(mean_correlations, std_correlations)) 
                 if not (np.isnan(mean) or np.isnan(std))]

if valid_indices:
    plot_dims = [dims[i] for i in valid_indices]
    plot_means = [mean_correlations[i] for i in valid_indices]
    plot_stds = [std_correlations[i] for i in valid_indices]
    
    # Feature Correlation (purple)
    plt.plot(plot_dims, plot_means, color='#648FFF', linewidth=2, label='Feature Correlation', marker='^', markersize=6)
    plt.fill_between(plot_dims, 
                     np.array(plot_means) - np.array(plot_stds), 
                     np.array(plot_means) + np.array(plot_stds),
                     color='#648FFF', alpha=0.3)
    
    # Formatting
    plt.xlabel("Latent Space Dimension", fontsize=16, fontname="Arial")
    plt.ylabel("Mean Absolute Correlation", fontsize=16, fontname="Arial")
    plt.title("Feature Correlation over Latent Dimensions", fontsize=18, fontname="Arial")
    plt.xticks(fontsize=14, fontname="Arial")
    plt.yticks(fontsize=14, fontname="Arial")
    
    # Set reasonable y-axis range (correlation is typically 0-1)
    y_min = 0.0#max(0.0, min(plot_means) - max(plot_stds) - 0.05)
    y_max = 1.0#min(1.0, max(plot_means) + max(plot_stds) + 0.05)
    plt.ylim(y_min, y_max)
    
    plt.grid(True, linestyle="--", alpha=0.6)
    
    # Save the figure
    # plt.savefig("../../results/latent_dim_correlation_13.png", dpi=300, bbox_inches="tight")
    #plt.savefig("../../results/latent_dim_mean_correlation_13.eps", dpi=300, bbox_inches="tight")
    
    plt.show()
    
    print(f"✅ Feature correlation plot saved with {len(plot_dims)} data points")
    print("📝 Note: Lower correlation values indicate better feature independence")
else:
    print("❌ No valid correlation data found for plotting")
# Out:
# 📈 Creating Plot 3: Feature Correlation over Latent Dimensions
# ✅ Feature correlation plot saved with 13 data points
# 📝 Note: Lower correlation values indicate better feature independence

# %%
# PLOT 3: Feature Correlation over Latent Dimensions
print("📈 Creating Plot 3: Feature Correlation over Latent Dimensions")

plt.figure(figsize=(8, 6))

# Extract data
mean_correlations = summary_stats['mean_correlation']
std_correlations = summary_stats['std_correlation']

# Remove any NaN values for plotting
valid_indices = [i for i, (mean, std) in enumerate(zip(mean_correlations, std_correlations)) 
                 if not (np.isnan(mean) or np.isnan(std))]

if valid_indices:
    plot_dims = [dims[i] for i in valid_indices]
    plot_means = [mean_correlations[i] for i in valid_indices]
    plot_stds = [std_correlations[i] for i in valid_indices]
    
    # Feature Correlation with transparent, thin error bars
    plt.errorbar(plot_dims, plot_means, yerr=plot_stds, 
                 color='#648FFF', linewidth=2, label='Feature Correlation', 
                 marker='^', markersize=6, capsize=3, capthick=0.8, 
                 elinewidth=0.8, markerfacecolor='#648FFF', markeredgecolor='#648FFF',
                 ecolor='#648FFF', alpha=1.0, # Main line stays opaque
                 errorevery=1, # Show error bars for every point
                 )
    
    # Make error bars more transparent by plotting them separately
    for i, (x, y, err) in enumerate(zip(plot_dims, plot_means, plot_stds)):
        plt.plot([x, x], [y-err, y+err], color='#648FFF', linewidth=0.8, alpha=0.4)
        plt.plot([x-0.05, x+0.05], [y-err, y-err], color='#648FFF', linewidth=0.8, alpha=0.4)  # Bottom cap
        plt.plot([x-0.05, x+0.05], [y+err, y+err], color='#648FFF', linewidth=0.8, alpha=0.4)  # Top cap
    
    # Plot the main line again to ensure it's on top and opaque
    plt.plot(plot_dims, plot_means, color='#648FFF', linewidth=2, marker='^', markersize=6, 
             markerfacecolor='#648FFF', markeredgecolor='#648FFF')
    
    # Formatting
    plt.xlabel("Latent Space Dimension", fontsize=16, fontname="Arial")
    plt.ylabel("Mean Absolute Correlation", fontsize=16, fontname="Arial")
    plt.title("Feature Correlation over Latent Dimensions", fontsize=18, fontname="Arial")
    plt.xticks(fontsize=14, fontname="Arial")
    plt.yticks(fontsize=14, fontname="Arial")
    
    # Set reasonable y-axis range (correlation is typically 0-1)
    y_min = 0.0#max(0.0, min(plot_means) - max(plot_stds) - 0.05)
    y_max = 0.7#min(1.0, max(plot_means) + max(plot_stds) + 0.05)
    plt.ylim(y_min, y_max)
    
    plt.grid(True, linestyle="--", alpha=0.6)
    
    # Save the figure
    # plt.savefig("../../results/latent_dim_correlation_13.png", dpi=300, bbox_inches="tight")
    #plt.savefig("brightfield_latent_dim_correlation.eps", dpi=300, bbox_inches="tight")
    
    plt.show()
    
    print(f"✅ Feature correlation plot saved with {len(plot_dims)} data points")
    print("📝 Note: Lower correlation values indicate better feature independence")
else:
    print("❌ No valid correlation data found for plotting")
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# 📈 Creating Plot 3: Feature Correlation over Latent Dimensions
# ✅ Feature correlation plot saved with 13 data points
# 📝 Note: Lower correlation values indicate better feature independence

# %%
# PLOT 4: Feature Covariance over Latent Dimensions
print("📈 Creating Plot 4: Feature Covariance over Latent Dimensions")

plt.figure(figsize=(8, 6))

# Extract data
mean_covariances = summary_stats['mean_covariance']
std_covariances = summary_stats['std_covariance']

# Remove any NaN values for plotting
valid_indices = [i for i, (mean, std) in enumerate(zip(mean_covariances, std_covariances)) 
                 if not (np.isnan(mean) or np.isnan(std))]

if valid_indices:
    plot_dims = [dims[i] for i in valid_indices]
    plot_means = [mean_covariances[i] for i in valid_indices]
    plot_stds = [std_covariances[i] for i in valid_indices]
    
    # Feature Covariance (green)
    plt.plot(plot_dims, plot_means, color='#648FFF', linewidth=2, label='Feature Covariance', marker='d', markersize=6)
    plt.fill_between(plot_dims, 
                     np.array(plot_means) - np.array(plot_stds), 
                     np.array(plot_means) + np.array(plot_stds),
                     color='#648FFF', alpha=0.3)
    
    # Formatting
    plt.xlabel("Latent Space Dimension", fontsize=16, fontname="Arial")
    plt.ylabel("Absolute Sum of Covariance", fontsize=16, fontname="Arial")
    plt.title("Feature Covariance over Latent Dimensions", fontsize=18, fontname="Arial")
    plt.xticks(fontsize=14, fontname="Arial")
    plt.yticks(fontsize=14, fontname="Arial")
    
    # Set reasonable y-axis range 
    y_min = -2#max(-1, min(plot_means) - max(plot_stds) - 0.05)
    y_max = 20#max(plot_means) + max(plot_stds) + 0.05
    plt.ylim(y_min, y_max)
    
    plt.grid(True, linestyle="--", alpha=0.6)
    
    # Save the figure
    # plt.savefig("../../results/latent_dim_covariance_13.png", dpi=300, bbox_inches="tight")
    # plt.savefig("../../results/latent_dim_covariance_13.eps", dpi=300, bbox_inches="tight")
    
    plt.show()
    
    print(f"✅ Feature covariance plot saved with {len(plot_dims)} data points")
    print("📝 Note: Lower covariance values indicate better feature independence")
else:
    print("❌ No valid covariance data found for plotting")
# Out:
# 📈 Creating Plot 4: Feature Covariance over Latent Dimensions
# ✅ Feature covariance plot saved with 13 data points
# 📝 Note: Lower covariance values indicate better feature independence
