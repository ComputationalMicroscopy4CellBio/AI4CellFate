# %%
import sys
import os
import numpy as np
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
sys.path.append(os.path.abspath("../.."))  #TODO: MAKE THE SRC PACKAGE WORK
from src.training.train import train_autoencoder, train_cellfate
from src.evaluation.evaluate import *
from src.training.loss_functions import *
from src.preprocessing.preprocessing_functions import *
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from src.models import Encoder, Decoder, Discriminator, mlp_classifier, complex_mlp_classifier
from src.utils import *
from tensorflow.keras import layers, Sequential
import tensorflow as tf
from sklearn.utils.class_weight import compute_class_weight

# %%
test_labels = np.load('/Users/inescunha/Documents/GitHub/AI4CellFate/data/labels/test_labels.npy')
train_tracks = np.load("/Users/inescunha/Documents/GitHub/AI4CellFate/data/tracks/train_tracks.npy")
train_labels = np.load("/Users/inescunha/Documents/GitHub/AI4CellFate/data/labels/train_labels.npy")
test_tracks = np.load("/Users/inescunha/Documents/GitHub/AI4CellFate/data/tracks/test_tracks.npy")

# Extract original features (13 features)
train_tracks_features_orig = train_tracks[:, 0, 4:17] 
test_tracks_features_orig = test_tracks[:, 0, 4:17]

# Calculate FRET_std (coefficient of variation)
# FRET_std = sqrt(CFP_std^2 + YFP_std^2) / (CFP_avg + YFP_avg)
# CFP_std is at index 3, YFP_std is at index 4, CFP_avg is at index 1, YFP_avg is at index 2
fret_std_train = np.sqrt(train_tracks_features_orig[:, 3]**2 + train_tracks_features_orig[:, 4]**2) / (train_tracks_features_orig[:, 1] + train_tracks_features_orig[:, 2])
fret_std_test = np.sqrt(test_tracks_features_orig[:, 3]**2 + test_tracks_features_orig[:, 4]**2) / (test_tracks_features_orig[:, 1] + test_tracks_features_orig[:, 2])

# Insert FRET_std as the second feature (index 1)
train_tracks_features = np.insert(train_tracks_features_orig, 1, fret_std_train, axis=1)
test_tracks_features = np.insert(test_tracks_features_orig, 1, fret_std_test, axis=1)

print(f"Original train features shape: {train_tracks_features_orig.shape}")
print(f"New train features shape: {train_tracks_features.shape}")
print(f"Original test features shape: {test_tracks_features_orig.shape}")
print(f"New test features shape: {test_tracks_features.shape}")
# Out:
# Original train features shape: (1108, 13)
# New train features shape: (1108, 14)
# Original test features shape: (277, 13)
# New test features shape: (277, 14)
# /var/folders/ds/_m8m03r135b5r67hc6xgtxt00000gn/T/ipykernel_14098/1319925203.py:13: RuntimeWarning: invalid value encountered in divide
#   fret_std_train = np.sqrt(train_tracks_features_orig[:, 3]**2 + train_tracks_features_orig[:, 4]**2) / (train_tracks_features_orig[:, 1] + train_tracks_features_orig[:, 2])

# %% [markdown]
# FEATURES:
#     "cell_av_FRET_norm", "FRET_std", "CFP_av", "YFP_av",
#     "CFP_std", "YFP_std", "MajorAxisLength", "MinorAxisLength", "Eccentricity", "EquivDiameter",
#     "Perimeter", "INT_av", "Area", "Aspect_Ratio", "mitosis_time", "fate"

# %%
# Feature names corresponding to their indices 
feature_names = ["FRET_avg", "FRET_std", "CFP_avg", "YFP_avg", 
                 "CFP_std", "YFP_std", "MajorAxisLength", "MinorAxisLength", 
                 "Eccentricity", "Diameter", "Perimeter", "Intensity_avg", "Area", "Aspect_Ratio"]

# Generate all unique feature pairs (14 choose 2 = 91 combinations)
import itertools
combinations = list(itertools.combinations(range(14), 2))

# Generate formatted output
for i, (f1, f2) in enumerate(combinations, 1):
    print(f" {i}: [{feature_names[f1]}, {feature_names[f2]}]")
# Out:
#  1: [FRET_avg, FRET_std]
#  2: [FRET_avg, CFP_avg]
#  3: [FRET_avg, YFP_avg]
#  4: [FRET_avg, CFP_std]
#  5: [FRET_avg, YFP_std]
#  6: [FRET_avg, MajorAxisLength]
#  7: [FRET_avg, MinorAxisLength]
#  8: [FRET_avg, Eccentricity]
#  9: [FRET_avg, Diameter]
#  10: [FRET_avg, Perimeter]
#  11: [FRET_avg, Intensity_avg]
#  12: [FRET_avg, Area]
#  13: [FRET_avg, Aspect_Ratio]
#  14: [FRET_std, CFP_avg]
#  15: [FRET_std, YFP_avg]
#  16: [FRET_std, CFP_std]
#  17: [FRET_std, YFP_std]
#  18: [FRET_std, MajorAxisLength]
#  19: [FRET_std, MinorAxisLength]
#  20: [FRET_std, Eccentricity]
#  21: [FRET_std, Diameter]
#  22: [FRET_std, Perimeter]
#  23: [FRET_std, Intensity_avg]
#  24: [FRET_std, Area]
#  25: [FRET_std, Aspect_Ratio]
#  26: [CFP_avg, YFP_avg]
#  27: [CFP_avg, CFP_std]
#  28: [CFP_avg, YFP_std]
#  29: [CFP_avg, MajorAxisLength]
#  30: [CFP_avg, MinorAxisLength]
#  31: [CFP_avg, Eccentricity]
#  32: [CFP_avg, Diameter]
#  33: [CFP_avg, Perimeter]
#  34: [CFP_avg, Intensity_avg]
#  35: [CFP_avg, Area]
#  36: [CFP_avg, Aspect_Ratio]
#  37: [YFP_avg, CFP_std]
#  38: [YFP_avg, YFP_std]
#  39: [YFP_avg, MajorAxisLength]
#  40: [YFP_avg, MinorAxisLength]
#  41: [YFP_avg, Eccentricity]
#  42: [YFP_avg, Diameter]
#  43: [YFP_avg, Perimeter]
#  44: [YFP_avg, Intensity_avg]
#  45: [YFP_avg, Area]
#  46: [YFP_avg, Aspect_Ratio]
#  47: [CFP_std, YFP_std]
#  48: [CFP_std, MajorAxisLength]
#  49: [CFP_std, MinorAxisLength]
#  50: [CFP_std, Eccentricity]
#  51: [CFP_std, Diameter]
#  52: [CFP_std, Perimeter]
#  53: [CFP_std, Intensity_avg]
#  54: [CFP_std, Area]
#  55: [CFP_std, Aspect_Ratio]
#  56: [YFP_std, MajorAxisLength]
#  57: [YFP_std, MinorAxisLength]
#  58: [YFP_std, Eccentricity]
#  59: [YFP_std, Diameter]
#  60: [YFP_std, Perimeter]
#  61: [YFP_std, Intensity_avg]
#  62: [YFP_std, Area]
#  63: [YFP_std, Aspect_Ratio]
#  64: [MajorAxisLength, MinorAxisLength]
#  65: [MajorAxisLength, Eccentricity]
#  66: [MajorAxisLength, Diameter]
#  67: [MajorAxisLength, Perimeter]
#  68: [MajorAxisLength, Intensity_avg]
#  69: [MajorAxisLength, Area]
#  70: [MajorAxisLength, Aspect_Ratio]
#  71: [MinorAxisLength, Eccentricity]
#  72: [MinorAxisLength, Diameter]
#  73: [MinorAxisLength, Perimeter]
#  74: [MinorAxisLength, Intensity_avg]
#  75: [MinorAxisLength, Area]
#  76: [MinorAxisLength, Aspect_Ratio]
#  77: [Eccentricity, Diameter]
#  78: [Eccentricity, Perimeter]
#  79: [Eccentricity, Intensity_avg]
#  80: [Eccentricity, Area]
#  81: [Eccentricity, Aspect_Ratio]
#  82: [Diameter, Perimeter]
#  83: [Diameter, Intensity_avg]
#  84: [Diameter, Area]
#  85: [Diameter, Aspect_Ratio]
#  86: [Perimeter, Intensity_avg]
#  87: [Perimeter, Area]
#  88: [Perimeter, Aspect_Ratio]
#  89: [Intensity_avg, Area]
#  90: [Intensity_avg, Aspect_Ratio]
#  91: [Area, Aspect_Ratio]

# %% [markdown]
# # Hyperparameter optimisation and cross-validation

# %%
from src.training.hyperparameter_example import *

results = run_tabular_hyperparameter_optimization(
    train_tracks_features, 
    train_labels, 
    test_tracks_features, 
    test_labels,
    feature_names
)
# Out:
# 🚀 Starting Comprehensive Hyperparameter Optimization
# ============================================================
# Features: 14
# Feature pairs to test: 91
# Training samples: 1108
# Test samples: 277
#
# 🚀 FEATURE PAIR COMPARISON
# ==================================================
# Step 1: Finding globally best hyperparameters...
# 🔍 Finding global best hyperparameters using 5 feature pairs...
#   Testing pair 1/5: [YFP_avg, Eccentricity]
# WARNING:tensorflow:5 out of the last 15 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x322dc8b80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 15 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x322dcaef0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2025-09-07 18:55:08.834767: I tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: INVALID_ARGUMENT: Incompatible shapes: [0] vs. [2]
# 	 [[{{function_node __inference_one_step_on_data_254788}}{{node adam/truediv_3}}]]
# 2025-09-07 18:57:26.763868: I tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: INVALID_ARGUMENT: Incompatible shapes: [16] vs. [0]
# 	 [[{{function_node __inference_one_step_on_data_591357}}{{node adam/truediv_11}}]]
#   Testing pair 2/5: [FRET_std, Intensity_avg]
# 2025-09-07 19:12:13.215218: I tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: INVALID_ARGUMENT: Incompatible shapes: [0] vs. [16,16]
# 	 [[{{function_node __inference_one_step_on_data_2096709}}{{node adam/truediv_9}}]]
#   Testing pair 3/5: [YFP_std, MajorAxisLength]
#   Testing pair 4/5: [Intensity_avg, Area]
#   Testing pair 5/5: [FRET_avg, FRET_std]
# 2025-09-07 20:00:43.740149: I tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: INVALID_ARGUMENT: Incompatible shapes: [2] vs. [0]
# 	 [[{{function_node __inference_one_step_on_data_4971122}}{{node adam/Mul_3}}]]
# 🏆 Global best hyperparameters found:
#    CV Accuracy: 0.6637 ± 0.0069
#    Parameters: {'hidden_layers': [32], 'dropout_rate': 0.5, 'learning_rate': 0.001}
#
# Step 2: Evaluating all feature pairs with fixed architecture...
# 🔬 Evaluating all 91 feature pairs with fixed architecture:
#    Architecture: {'hidden_layers': [32], 'dropout_rate': 0.5, 'learning_rate': 0.001}
#    Progress: 1/91 pairs...
#    Progress: 11/91 pairs...
#    Progress: 21/91 pairs...
#    Progress: 31/91 pairs...
#    Progress: 41/91 pairs...
#    Progress: 51/91 pairs...
#    Progress: 61/91 pairs...
#    Progress: 71/91 pairs...
#    Progress: 81/91 pairs...
#    Progress: 91/91 pairs...
# ✅ Completed evaluation of all feature pairs!
#    Mean CV accuracy: 0.6054 ± 0.0528
#    Mean test accuracy: 0.5997 ± 0.0677
#    Best test accuracy: 0.7117
#
# 💾 Saved results as numpy arrays:
#    - feature_pair_names.npy
#    - feature_pair_cv_accuracies.npy
#    - feature_pair_cv_stds.npy
#    - feature_pair_test_accuracies.npy
#    - feature_pair_test_precisions.npy
#    - feature_pair_confusion_matrices.npy
#
# 🎯 SUMMARY:
#    Total feature pairs evaluated: 91
#    Best CV accuracy: 0.6955
#    Best test accuracy: 0.7117
#    Best feature pair: FRET_avg + Diameter
#    Architecture used: {'hidden_layers': [32], 'dropout_rate': 0.5, 'learning_rate': 0.001}

# %%
feature_pair_confusion_matrices = np.load("/Users/inescunha/Documents/GitHub/AI4CellFate/notebooks/manuscript/feature_pair_confusion_matrices.npy")
feature_pair_names = np.load("/Users/inescunha/Documents/GitHub/AI4CellFate/notebooks/manuscript/feature_pair_names.npy")
feature_pair_cv_accuracy = np.load("/Users/inescunha/Documents/GitHub/AI4CellFate/notebooks/manuscript/feature_pair_cv_accuracies.npy")
feature_pair_test_accuracies = np.load("/Users/inescunha/Documents/GitHub/AI4CellFate/notebooks/manuscript/feature_pair_test_accuracies.npy")

# %%
feature_pair_names[np.argmax(feature_pair_cv_accuracy)]
# Out:
# 'FRET_avg + Area'

# %%
feature_pairs = np.arange(1, 92)

# Plot
plt.figure(figsize=(8, 6))

# Precision (orange)
#plt.plot(feature_pairs, precision_tabular, color='orange', linewidth=2, label='Precision')

# Accuracy (purple)
plt.plot(feature_pairs, feature_pair_cv_accuracy, color='orange', linewidth=2, label='Tabular features accuracy')

# Add horizontal dotted line for AICellFate model precision
#plt.axhline(y=0.745, color='orange', linestyle='dotted', linewidth=2, label='AICellFate model precision')
plt.axhline(y=0.72, color='gray', linestyle='dotted', linewidth=2, label='Latent features accuracy') ### this is the mean precision value from AICellFate on the first frame

# # False Positives (green)
# plt.plot(feature_pairs, false_positives_tabular, color='green', linewidth=2, label='False Positives')

# # False Negatives (blue)
# plt.plot(feature_pairs, false_negatives_tabular, color='blue', linewidth=2, label='False Negatives')

# Formatting
plt.xlabel("Chosen feature combination", fontsize=16, fontname="Arial")
plt.ylabel("Confusion matrix metrics", fontsize=16, fontname="Arial")
plt.title("Tabular data Accuracy over chosen feature combinations", fontsize=18, fontname="Arial")
plt.xticks(fontsize=14, fontname="Arial")
plt.yticks(fontsize=14, fontname="Arial")
plt.ylim(0.4, 0.8)  # Set y-axis range
#plt.title("Tabular data with MLP")
plt.grid(True, linestyle="--", alpha=0.6)
plt.legend(fontsize=14)
# Save the figure with high quality
#plt.savefig("accuracy_all_tab_feat_combination.eps", dpi=300, bbox_inches="tight")
plt.show()

# %% [markdown]
# ## All features training

# %%
train_tracks_features.shape, train_labels.shape
# Out:
# ((1108, 14), (1108,))

# %%
train_tracks_features
# Out:
# array([[8.8405502e-01, 1.7424601e-01, 4.1251654e+02, ..., 7.9388660e+02,
#         1.2900000e+02, 1.1611936e+00],
#        [0.0000000e+00, 2.0999870e-01, 3.1678671e+02, ..., 9.7603491e+02,
#         2.2400000e+02, 1.1247395e+00],
#        [1.0429950e+00, 1.7503758e-01, 1.3490938e+03, ..., 2.9264309e+03,
#         1.2700000e+02, 1.2929583e+00],
#        ...,
#        [9.3932021e-01, 1.8343653e-01, 4.3422519e+02, ..., 8.9144910e+02,
#         1.1300000e+02, 2.0359247e+00],
#        [1.0096453e+00, 1.7966200e-01, 1.2565077e+03, ..., 2.6786211e+03,
#         6.4000000e+01, 1.4603589e+00],
#        [1.1892573e+00, 3.1127298e-01, 1.0424686e+03, ..., 2.3389456e+03,
#         8.6000000e+01, 1.7699872e+00]], dtype=float32)

# %%
train_tracks_features_orig
# Out:
# array([[8.8405502e-01, 4.1251654e+02, 3.8137009e+02, ..., 7.9388660e+02,
#         1.2900000e+02, 1.1611936e+00],
#        [0.0000000e+00, 3.1678671e+02, 6.5924823e+02, ..., 9.7603491e+02,
#         2.2400000e+02, 1.1247395e+00],
#        [1.0429950e+00, 1.3490938e+03, 1.5773373e+03, ..., 2.9264309e+03,
#         1.2700000e+02, 1.2929583e+00],
#        ...,
#        [9.3932021e-01, 4.3422519e+02, 4.5722391e+02, ..., 8.9144910e+02,
#         1.1300000e+02, 2.0359247e+00],
#        [1.0096453e+00, 1.2565077e+03, 1.4221135e+03, ..., 2.6786211e+03,
#         6.4000000e+01, 1.4603589e+00],
#        [1.1892573e+00, 1.0424686e+03, 1.2964769e+03, ..., 2.3389456e+03,
#         8.6000000e+01, 1.7699872e+00]], dtype=float32)

# %%
from tensorflow.keras import layers, Sequential
import tensorflow as tf
from sklearn.utils.class_weight import compute_class_weight

conf_matrix_tabular = np.zeros((3, 2, 2)) 

def create_best_mlp_model(input_dim):
    """Create the best MLP model found during hyperparameter optimization."""
    model = tf.keras.Sequential([
        # Input layer with batch normalization
        tf.keras.layers.InputLayer(input_shape=(input_dim,)),
        tf.keras.layers.BatchNormalization(),
        
        # Hidden layer
        tf.keras.layers.Dense(32, activation='relu'),
        tf.keras.layers.Dropout(0.5),
        
        # Output layer
        tf.keras.layers.Dense(2, activation='softmax')
    ])
    
    # Compile with best learning rate
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )
    
    return model

for seed in [42, 43, 44]:

    class_weights = compute_class_weight('balanced', classes=np.unique(train_labels.flatten()), y=train_labels.flatten())
    class_weights = dict(enumerate(class_weights))

    tf.keras.utils.set_random_seed(seed)
    np.random.seed(seed)

    classifier = create_best_mlp_model(input_dim=train_tracks_features_orig[:,:].shape[1]) #[:, [3, 8]] 
    #classifier = simple_mlp_classifier(latent_dim=time_norm_train_track[:,frame,:].shape[1])

    # Train the classifier
    classifier.compile(loss='sparse_categorical_crossentropy', optimizer= tf.keras.optimizers.Adam(learning_rate=0.001), metrics=['accuracy'])
    classifier.summary()

    x_train_tracks, x_val_tracks, y_train_tracks, y_val_tracks = train_test_split(train_tracks_features_orig, train_labels, test_size=0.2, random_state=42, stratify=train_labels) # 42 random state

    history = classifier.fit(x_train_tracks, y_train_tracks, batch_size=32, epochs=50, validation_data=(x_val_tracks, y_val_tracks), class_weight=class_weights) 

    y_pred = classifier.predict(test_tracks_features_orig)

    num_classes = 2
    threshold = 0.5
    y_pred_classes = np.argmax(y_pred, axis=1)

    # Calculate confusion matrix
    cm = confusion_matrix(test_labels, y_pred_classes)

    class_sums = cm.sum(axis=1, keepdims=True)
    conf_matrix_normalized = cm / class_sums

    print(conf_matrix_normalized)

    conf_matrix_tabular[seed-42] = conf_matrix_normalized
# Out:
# Model: "sequential_15"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ batch_normalization_15          │ (None, 13)             │            52 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_40 (Dense)                │ (None, 32)             │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_25 (Dropout)            │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_41 (Dense)                │ (None, 2)              │            66 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 566 (2.21 KB)
#  Trainable params: 540 (2.11 KB)
#  Non-trainable params: 26 (104.00 B)
# Epoch 1/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4531 - loss: 0.7309 - val_accuracy: 0.2072 - val_loss: 1.5236
# Epoch 2/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5693 - loss: 0.6963 - val_accuracy: 0.2207 - val_loss: 1.2180
# Epoch 3/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 976us/step - accuracy: 0.5730 - loss: 0.6837 - val_accuracy: 0.2432 - val_loss: 1.0319
# Epoch 4/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 897us/step - accuracy: 0.5687 - loss: 0.6639 - val_accuracy: 0.3063 - val_loss: 0.9280
# Epoch 5/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 899us/step - accuracy: 0.5924 - loss: 0.7030 - val_accuracy: 0.3829 - val_loss: 0.8183
# Epoch 6/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 920us/step - accuracy: 0.5474 - loss: 0.6704 - val_accuracy: 0.4550 - val_loss: 0.7500
# Epoch 7/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 926us/step - accuracy: 0.5690 - loss: 0.6673 - val_accuracy: 0.5045 - val_loss: 0.6990
# Epoch 8/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 928us/step - accuracy: 0.5831 - loss: 0.6224 - val_accuracy: 0.5225 - val_loss: 0.6637
# Epoch 9/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 943us/step - accuracy: 0.5934 - loss: 0.6342 - val_accuracy: 0.5676 - val_loss: 0.6314
# Epoch 10/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 924us/step - accuracy: 0
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [[0.61038961 0.38961039]
#  [0.30434783 0.69565217]]

# %%
#np.save("conf_matrix_tabular_13_features.npy", conf_matrix_tabular)

# %%
precision_tabular = np.zeros((conf_matrix_tabular.shape[0]))
accuracy_tabular = np.zeros((conf_matrix_tabular.shape[0]))
false_positives_tabular = np.zeros((conf_matrix_tabular.shape[0]))
false_negatives_tabular = np.zeros((conf_matrix_tabular.shape[0]))

for size in range(conf_matrix_tabular.shape[0]):
    conf_matrix = conf_matrix_tabular[size]
    precision_tabular[size] = conf_matrix[0,0] / (conf_matrix[0,0] + conf_matrix[1,0])
    accuracy_tabular[size] = (conf_matrix[0,0] + conf_matrix[1,1]) / np.sum(conf_matrix)
    false_positives_tabular[size] = conf_matrix[1,0] #/ np.sum(conf_matrix[1,:])
    false_negatives_tabular[size] = conf_matrix[0,1] #/ np.sum(conf_matrix[0,:])

# %%
accuracy_tabular
# Out:
# array([0.5, 0.5, 0.5])

# %% [markdown]
# # Previous

# %%
import numpy as np
import tensorflow as tf
from sklearn.utils.class_weight import compute_class_weight
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import itertools

# Define config
config = {
    'batch_size': 30,
    'epochs': 50,
    'learning_rate': 0.001,
    'seed': 42,
}

# Set seed
tf.keras.utils.set_random_seed(config['seed'])
np.random.seed(config['seed'])

# All unique feature pairs (14 choose 2 = 91)
feature_pairs = list(itertools.combinations(range(14), 2))
config['n_feature_pairs'] = len(feature_pairs)

# Initialize container for confusion matrices
conf_matrix_tabular = np.zeros((config['n_feature_pairs'], 2, 2))

# Loop over all unique feature combinations
for i, selected_features in enumerate(feature_pairs):
    print(f"Run {i+1}/{config['n_feature_pairs']} — Using features: {selected_features}")

    # Subset the data
    X_train = train_tracks_features[:, selected_features]
    X_test = test_tracks_features[:, selected_features]

    # Train/val split
    X_val, X_test_final, y_val, y_test_final = train_test_split(X_test, test_labels, test_size=0.5, random_state=42)

    # Class weights
    class_weights = compute_class_weight('balanced', classes=np.unique(train_labels), y=train_labels)
    class_weights = dict(enumerate(class_weights))

    # Build model
    classifier = complex_mlp_classifier(latent_dim=2)
    classifier.compile(loss='sparse_categorical_crossentropy',
                       optimizer=tf.keras.optimizers.Adam(learning_rate=config['learning_rate']),
                       metrics=['accuracy'])

    # Train
    try:
        tf.keras.backend.clear_session()
        history = classifier.fit(
            X_train, train_labels,
            batch_size=config['batch_size'],
            epochs=config['epochs'],
            validation_data=(X_val, y_val),
            class_weight=class_weights,
            verbose=0
        )
    except Exception as e:
        print(f"Continuing training without classification check... {e}")
        # Clean up in case of error
        try:
            del classifier
        except Exception:
            pass
        tf.keras.backend.clear_session()
        history = None

    # Predict
    y_pred = classifier.predict(X_test_final, verbose=0)
    y_pred_classes = np.argmax(y_pred, axis=1)

    # Confusion Matrix
    cm = confusion_matrix(y_test_final, y_pred_classes)
    cm_normalized = cm / cm.sum(axis=1, keepdims=True)
    conf_matrix_tabular[i] = cm_normalized

# Save results
# np.save("confusion_matrices_all_feature_combinations.npy", conf_matrix_tabular)
# Out:
# Run 1/91 — Using features: (0, 1)
# Run 2/91 — Using features: (0, 2)
# Run 3/91 — Using features: (0, 3)
# Run 4/91 — Using features: (0, 4)
# Run 5/91 — Using features: (0, 5)
# Run 6/91 — Using features: (0, 6)
# Run 7/91 — Using features: (0, 7)
# Run 8/91 — Using features: (0, 8)
# Run 9/91 — Using features: (0, 9)
# Run 10/91 — Using features: (0, 10)
# Run 11/91 — Using features: (0, 11)
# Run 12/91 — Using features: (0, 12)
# Run 13/91 — Using features: (0, 13)
# Run 14/91 — Using features: (1, 2)
# Run 15/91 — Using features: (1, 3)
# Run 16/91 — Using features: (1, 4)
# Run 17/91 — Using features: (1, 5)
# Run 18/91 — Using features: (1, 6)
# Run 19/91 — Using features: (1, 7)
# Run 20/91 — Using features: (1, 8)
# Run 21/91 — Using features: (1, 9)
# Run 22/91 — Using features: (1, 10)
# Run 23/91 — Using features: (1, 11)
# Run 24/91 — Using features: (1, 12)
# Run 25/91 — Using features: (1, 13)
# Run 26/91 — Using features: (2, 3)
# Run 27/91 — Using features: (2, 4)
# Run 28/91 — Using features: (2, 5)
# Run 29/91 — Using features: (2, 6)
# Run 30/91 — Using features: (2, 7)
# Run 31/91 — Using features: (2, 8)
# Run 32/91 — Using features: (2, 9)
# Run 33/91 — Using features: (2, 10)
# Run 34/91 — Using features: (2, 11)
# Run 35/91 — Using features: (2, 12)
# Run 36/91 — Using features: (2, 13)
# Run 37/91 — Using features: (3, 4)
# Run 38/91 — Using features: (3, 5)
# Run 39/91 — Using features: (3, 6)
# Run 40/91 — Using features: (3, 7)
# Run 41/91 — Using features: (3, 8)
# Run 42/91 — Using features: (3, 9)
# Run 43/91 — Using features: (3, 10)
# Run 44/91 — Using features: (3, 11)
# Run 45/91 — Using features: (3, 12)
# Run 46/91 — Using features: (3, 13)
# Run 47/91 — Using features: (4, 5)
# Run 48/91 — Using features: (4, 6)
# Run 49/91 — Using features: (4, 7)
# Run 50/91 — Using features: (4, 8)
# Run 51/91 — Using features: (4, 9)
# Run 52/91 — Using features: (4, 10)
# Run 53/91 — Using features: (4, 11)
# Run 54/91 — Using features: (4, 12)
# Run 55/91 — Using features: (4, 13)
# Run 56/91 — Using features: (5, 6)
# Run 57/91 — Using features: (5, 7)
# Run 58/91 — Using features: (5, 8)
# Run 59/91 — Using features: (5, 9)
# Run 60/91 — Using features: (5, 10)
# Run 61/91 — Using features: (5, 11)
# Run 62/91 — Using features: (5, 12)
# Run 63/91 — Using features: (5, 13)
# Run 64/91 — Using features: (6, 7)
# Run 65/91 — Using features: (6, 8)
# Run 66/91 — Using features: (6, 9)
# Run 67/91 — Using features: (6, 10)
# Run 68/91 — Using features: (6, 11)
# Run 69/91 — Using features: (6, 12)
# Run 70/91 — Using features: (6, 13)
# Run 71/91 — Using features: (7, 8)
# Run 72/91 — Using features: (7, 9)
# Run 73/91 — Using features: (7, 10)
# Run 74/91 — Using features: (7, 11)
# Run 75/91 — Using features: (7, 12)
# Run 76/91 — Using features: (7, 13)
# Run 77/91 — Using features: (8, 9)
# Run 78/91 — Using features: (8, 10)
# Run 79/91 — Using features: (8, 11)
# Run 80/91 — Using features: (8, 12)
# Run 81/91 — Using features: (8, 13)
# Run 82/91 — Using features: (9, 10)
# Run 83/91 — Using features: (9, 11)
# Run 84/91 — Using features: (9, 12)
# Run 85/91 — Using features: (9, 13)
# Run 86/91 — Using features: (10, 11)
# Run 87/91 — Using features: (10, 12)
# Run 88/91 — Using features: (10, 13)
# Run 89/91 — Using features: (11, 12)
# Run 90/91 — Using features: (11, 13)
# Run 91/91 — Using features: (12, 13)

# %%
#np.save("conf_matrices_all_possible_feat_comb.npy", conf_matrix_tabular)

# %%
conf_matrix_tabular = np.load("conf_matrices_all_possible_feat_comb.npy")

# %%
precision_tabular = np.zeros((conf_matrix_tabular.shape[0]))
accuracy_tabular = np.zeros((conf_matrix_tabular.shape[0]))
false_positives_tabular = np.zeros((conf_matrix_tabular.shape[0]))
false_negatives_tabular = np.zeros((conf_matrix_tabular.shape[0]))

for size in range(conf_matrix_tabular.shape[0]):
    conf_matrix = conf_matrix_tabular[size]
    precision_tabular[size] = conf_matrix[0,0] / (conf_matrix[0,0] + conf_matrix[1,0])
    accuracy_tabular[size] = (conf_matrix[0,0] + conf_matrix[1,1]) / np.sum(conf_matrix)
    false_positives_tabular[size] = conf_matrix[1,0] #/ np.sum(conf_matrix[1,:])
    false_negatives_tabular[size] = conf_matrix[0,1] #/ np.sum(conf_matrix[0,:])

# %%
# np.save("precision_2feattabular.npy", precision_tabular)
# np.save("accuracy_2feattabular.npy", accuracy_tabular)
# np.save("false_positives_2feattabular.npy", false_positives_tabular)
# np.save("false_negatives_2feattabular.npy", false_negatives_tabular)

# %%
feature_pairs = np.arange(1, 92)

# Plot
plt.figure(figsize=(8, 6))

# Precision (orange)
#plt.plot(feature_pairs, precision_tabular, color='orange', linewidth=2, label='Precision')

# Accuracy (purple)
plt.plot(feature_pairs, accuracy_tabular, color='orange', linewidth=2, label='Tabular features accuracy')

# Add horizontal dotted line for AICellFate model precision
#plt.axhline(y=0.745, color='orange', linestyle='dotted', linewidth=2, label='AICellFate model precision')
plt.axhline(y=0.72, color='gray', linestyle='dotted', linewidth=2, label='Latent features accuracy') ### this is the mean precision value from AICellFate on the first frame

# # False Positives (green)
# plt.plot(feature_pairs, false_positives_tabular, color='green', linewidth=2, label='False Positives')

# # False Negatives (blue)
# plt.plot(feature_pairs, false_negatives_tabular, color='blue', linewidth=2, label='False Negatives')

# Formatting
plt.xlabel("Chosen feature combination", fontsize=16, fontname="Arial")
plt.ylabel("Confusion matrix metrics", fontsize=16, fontname="Arial")
plt.title("Metrics", fontsize=18, fontname="Arial")
plt.xticks(fontsize=14, fontname="Arial")
plt.yticks(fontsize=14, fontname="Arial")
plt.ylim(0.4, 0.8)  # Set y-axis range
plt.title("Tabular data with MLP")
plt.grid(True, linestyle="--", alpha=0.6)
plt.legend(fontsize=14)
# Save the figure with high quality
#plt.savefig("accuracy_all_tab_feat_combination.eps", dpi=300, bbox_inches="tight")
plt.show()

# %%
feature_pairs = np.arange(1, 79)

# Plot
plt.figure(figsize=(8, 6))

# Precision (orange)
plt.plot(feature_pairs, precision_tabular, color='orange', linewidth=2, label='Tabular precision with complex MLP')

# Accuracy (purple)
#plt.plot(feature_pairs, accuracy_tabular, color='orange', linewidth=2, label='Tabular features accuracy')

# Add horizontal dotted line for AICellFate model precision
plt.axhline(y=0.75, color='black', linestyle='dotted', linewidth=2, label='Latent features precision')
#plt.axhline(y=0.72, color='gray', linestyle='dotted', linewidth=2, label='Latent features accuracy') ### this is the mean precision value from AICellFate on the first frame

# # False Positives (green)
# plt.plot(feature_pairs, false_positives_tabular, color='green', linewidth=2, label='False Positives')

# # False Negatives (blue)
# plt.plot(feature_pairs, false_negatives_tabular, color='blue', linewidth=2, label='False Negatives')

# Formatting
plt.xlabel("Chosen feature combination", fontsize=16, fontname="Arial")
plt.ylabel("Precision", fontsize=16, fontname="Arial")
plt.title("Metrics", fontsize=18, fontname="Arial")
plt.xticks(fontsize=14, fontname="Arial")
plt.yticks(fontsize=14, fontname="Arial")
plt.ylim(0.4, 0.8)  # Set y-axis range
plt.title("Model Precision over chosen tabular features", fontsize=18)
plt.grid(True, linestyle="--", alpha=0.6)
plt.legend(fontsize=14)
# Save the figure with high quality
plt.savefig("precision_tabular.eps", dpi=300, bbox_inches="tight")
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# ## Performance with smaller model

# %%
import numpy as np
import tensorflow as tf
from sklearn.utils.class_weight import compute_class_weight
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import itertools

# Define config
config = {
    'batch_size': 30,
    'epochs': 50,
    'learning_rate': 0.001,
    'seed': 42,
}

# Set seed
tf.keras.utils.set_random_seed(config['seed'])
np.random.seed(config['seed'])

# All unique feature pairs (13 choose 2 = 78)
feature_pairs = list(itertools.combinations(range(13), 2))
config['n_feature_pairs'] = len(feature_pairs)

# Initialize container for confusion matrices
conf_matrix_tabular = np.zeros((config['n_feature_pairs'], 2, 2))

# Loop over all unique feature combinations
for i, selected_features in enumerate(feature_pairs):
    print(f"Run {i+1}/{config['n_feature_pairs']} — Using features: {selected_features}")

    # Subset the data
    X_train = train_tracks_features[:, selected_features]
    X_test = test_tracks_features[:, selected_features]

    # Train/val split
    X_val, X_test_final, y_val, y_test_final = train_test_split(X_test, test_labels, test_size=0.5, random_state=42)

    # Class weights
    class_weights = compute_class_weight('balanced', classes=np.unique(train_labels), y=train_labels)
    class_weights = dict(enumerate(class_weights))

    # Build model
    classifier = mlp_classifier(latent_dim=2)
    classifier.compile(loss='sparse_categorical_crossentropy',
                       optimizer=tf.keras.optimizers.Adam(learning_rate=config['learning_rate']),
                       metrics=['accuracy'])

    # Train
    classifier.fit(X_train, train_labels,
                   batch_size=config['batch_size'],
                   epochs=config['epochs'],
                   validation_data=(X_val, y_val),
                   class_weight=class_weights,
                   verbose=0)

    # Predict
    y_pred = classifier.predict(X_test_final, verbose=0)
    y_pred_classes = np.argmax(y_pred, axis=1)

    # Confusion Matrix
    cm = confusion_matrix(y_test_final, y_pred_classes)
    cm_normalized = cm / cm.sum(axis=1, keepdims=True)
    conf_matrix_tabular[i] = cm_normalized
    

# Save results
# np.save("confusion_matrices_all_feature_combinations.npy", conf_matrix_tabular)
# Out:
# Run 1/78 — Using features: (0, 1)
# Run 2/78 — Using features: (0, 2)
# Run 3/78 — Using features: (0, 3)
# Run 4/78 — Using features: (0, 4)
# Run 5/78 — Using features: (0, 5)
# Run 6/78 — Using features: (0, 6)
# Run 7/78 — Using features: (0, 7)
# Run 8/78 — Using features: (0, 8)
# Run 9/78 — Using features: (0, 9)
# Run 10/78 — Using features: (0, 10)
# Run 11/78 — Using features: (0, 11)
# Run 12/78 — Using features: (0, 12)
# Run 13/78 — Using features: (1, 2)
# Run 14/78 — Using features: (1, 3)
# Run 15/78 — Using features: (1, 4)
# Run 16/78 — Using features: (1, 5)
# Run 17/78 — Using features: (1, 6)
# Run 18/78 — Using features: (1, 7)
# Run 19/78 — Using features: (1, 8)
# Run 20/78 — Using features: (1, 9)
# Run 21/78 — Using features: (1, 10)
# Run 22/78 — Using features: (1, 11)
# Run 23/78 — Using features: (1, 12)
# Run 24/78 — Using features: (2, 3)
# Run 25/78 — Using features: (2, 4)
# Run 26/78 — Using features: (2, 5)
# Run 27/78 — Using features: (2, 6)
# Run 28/78 — Using features: (2, 7)
# Run 29/78 — Using features: (2, 8)
# Run 30/78 — Using features: (2, 9)
# Run 31/78 — Using features: (2, 10)
# Run 32/78 — Using features: (2, 11)
# Run 33/78 — Using features: (2, 12)
# Run 34/78 — Using features: (3, 4)
# Run 35/78 — Using features: (3, 5)
# Run 36/78 — Using features: (3, 6)
# Run 37/78 — Using features: (3, 7)
# Run 38/78 — Using features: (3, 8)
# Run 39/78 — Using features: (3, 9)
# Run 40/78 — Using features: (3, 10)
# Run 41/78 — Using features: (3, 11)
# Run 42/78 — Using features: (3, 12)
# Run 43/78 — Using features: (4, 5)
# Run 44/78 — Using features: (4, 6)
# Run 45/78 — Using features: (4, 7)
# Run 46/78 — Using features: (4, 8)
# Run 47/78 — Using features: (4, 9)
# Run 48/78 — Using features: (4, 10)
# Run 49/78 — Using features: (4, 11)
# Run 50/78 — Using features: (4, 12)
# Run 51/78 — Using features: (5, 6)
# Run 52/78 — Using features: (5, 7)
# Run 53/78 — Using features: (5, 8)
# Run 54/78 — Using features: (5, 9)
# Run 55/78 — Using features: (5, 10)
# Run 56/78 — Using features: (5, 11)
# Run 57/78 — Using features: (5, 12)
# Run 58/78 — Using features: (6, 7)
# Run 59/78 — Using features: (6, 8)
# Run 60/78 — Using features: (6, 9)
# Run 61/78 — Using features: (6, 10)
# Run 62/78 — Using features: (6, 11)
# Run 63/78 — Using features: (6, 12)
# Run 64/78 — Using features: (7, 8)
# Run 65/78 — Using features: (7, 9)
# Run 66/78 — Using features: (7, 10)
# Run 67/78 — Using features: (7, 11)
# Run 68/78 — Using features: (7, 12)
# Run 69/78 — Using features: (8, 9)
# Run 70/78 — Using features: (8, 10)
# Run 71/78 — Using features: (8, 11)
# Run 72/78 — Using features: (8, 12)
# Run 73/78 — Using features: (9, 10)
# Run 74/78 — Using features: (9, 11)
# Run 75/78 — Using features: (9, 12)
# Run 76/78 — Using features: (10, 11)
# Run 77/78 — Using features: (10, 12)
# Run 78/78 — Using features: (11, 12)

# %%
#np.save("confusion_matrices_small_model_all_features.npy", conf_matrix_tabular)

# %%
conf_matrix_tabular = np.load("confusion_matrices_small_model_all_features.npy")

# %%
precision_tabular = np.zeros((conf_matrix_tabular.shape[0]))
accuracy_tabular_smallmp = np.zeros((conf_matrix_tabular.shape[0]))
false_positives_tabular = np.zeros((conf_matrix_tabular.shape[0]))
false_negatives_tabular = np.zeros((conf_matrix_tabular.shape[0]))

for size in range(conf_matrix_tabular.shape[0]):
    conf_matrix = conf_matrix_tabular[size]
    precision_tabular[size] = conf_matrix[0,0] / (conf_matrix[0,0] + conf_matrix[1,0] + 0.00001)
    accuracy_tabular_smallmp[size] = (conf_matrix[0,0] + conf_matrix[1,1]) / np.sum(conf_matrix)
    false_positives_tabular[size] = conf_matrix[1,0] #/ np.sum(conf_matrix[1,:])
    false_negatives_tabular[size] = conf_matrix[0,1] #/ np.sum(conf_matrix[0,:])

# %%
feature_pairs = np.arange(1, 79)

# Plot
plt.figure(figsize=(8, 6))

# Precision (orange)
plt.plot(feature_pairs, accuracy_tabular, color='orange', linewidth=2, label='Tabular accuracy with complex MLP')

# Accuracy (purple)
plt.plot(feature_pairs, accuracy_tabular_smallmp, color='violet', linewidth=2, label='Tabular accuracy with small MLP')

# Add horizontal dotted line for AICellFate model precision
#plt.axhline(y=0.745, color='orange', linestyle='dotted', linewidth=2, label='AICellFate model precision')
plt.axhline(y=0.72, color='gray', linestyle='dotted', linewidth=2, label='Latent features accuracy') ### this is the mean precision value from AICellFate on the first frame

# # False Positives (green)
# plt.plot(feature_pairs, false_positives_tabular, color='green', linewidth=2, label='False Positives')

# # False Negatives (blue)
# plt.plot(feature_pairs, false_negatives_tabular, color='blue', linewidth=2, label='False Negatives')

# Formatting
plt.xlabel("Chosen feature combination", fontsize=16, fontname="Arial")
plt.ylabel("Accuracy", fontsize=16, fontname="Arial")
plt.title("Metrics", fontsize=18, fontname="Arial")
plt.xticks(fontsize=14, fontname="Arial")
plt.yticks(fontsize=14, fontname="Arial")
plt.ylim(0.4, 0.8)  # Set y-axis range
plt.title("Models Accuracy over chosen tabular features", fontsize=18)
plt.grid(True, linestyle="--", alpha=0.6)
plt.legend(fontsize=14)
# Save the figure with high quality
#plt.savefig("multi_model_accuracy_tabular.eps", dpi=300, bbox_inches="tight")
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
feature_pairs = np.arange(1, 79)

# Plot
plt.figure(figsize=(8, 6))

# Precision (orange)
plt.plot(feature_pairs, accuracy_tabular, color='orange', linewidth=2, label='Tabular accuracy with complex MLP')

# Accuracy (purple)
plt.plot(feature_pairs, accuracy_tabular_smallmp, color='violet', linewidth=2, label='Tabular accuracy with small MLP')

# Add horizontal dotted line for AICellFate model precision
#plt.axhline(y=0.745, color='orange', linestyle='dotted', linewidth=2, label='AICellFate model precision')
plt.axhline(y=0.72, color='black', linestyle='dotted', linewidth=2, label='Latent features accuracy') ### this is the mean precision value from AICellFate on the first frame

# # False Positives (green)
# plt.plot(feature_pairs, false_positives_tabular, color='green', linewidth=2, label='False Positives')

# # False Negatives (blue)
# plt.plot(feature_pairs, false_negatives_tabular, color='blue', linewidth=2, label='False Negatives')

# Formatting
plt.xlabel("Chosen feature combination", fontsize=16, fontname="Arial")
plt.ylabel("Accuracy", fontsize=16, fontname="Arial")
plt.title("Metrics", fontsize=18, fontname="Arial")
plt.xticks(fontsize=14, fontname="Arial")
plt.yticks(fontsize=14, fontname="Arial")
plt.ylim(0.42, 0.82)  # Set y-axis range
plt.title("Models Accuracy over chosen tabular features", fontsize=18)
plt.grid(True, linestyle="--", alpha=0.6)
plt.legend(fontsize=14)
# Save the figure with high quality
#plt.savefig("multi_model_accuracy_tabular.eps", dpi=300, bbox_inches="tight")
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# ## All features

# %%
np.load("/Users/inescunha/Documents/GitHub/CellFate/data/temporal_study/all_confusion_matrices_tabular.npy")[0]
# Out:
# array([[0.63063063, 0.36936937],
#        [0.39285714, 0.60714286]])

# %%
from tensorflow.keras import layers, Sequential
import tensorflow as tf
from sklearn.utils.class_weight import compute_class_weight

conf_matrix_tabular = np.zeros((3, 2, 2)) 

for seed in [42, 43, 44]:

    class_weights = compute_class_weight('balanced', classes=np.unique(train_labels.flatten()), y=train_labels.flatten())
    class_weights = dict(enumerate(class_weights))

    tf.keras.utils.set_random_seed(seed)
    np.random.seed(seed)

    classifier = complex_mlp_classifier(latent_dim=train_tracks_features[:,:].shape[1]) #[:, [3, 8]] 
    #classifier = simple_mlp_classifier(latent_dim=time_norm_train_track[:,frame,:].shape[1])

    # Train the classifier
    classifier.compile(loss='sparse_categorical_crossentropy', optimizer= tf.keras.optimizers.Adam(learning_rate=config['learning_rate']), metrics=['accuracy'])
    classifier.summary()

    x_val_tracks, x_test_tracks, y_val_tracks, y_test_tracks = train_test_split(test_tracks_features[:,:], test_labels, test_size=0.5, random_state=42) # 42 random state

    history = classifier.fit(train_tracks_features[:,:], train_labels, batch_size=config['batch_size'], epochs=config['epochs'], validation_data=(x_val_tracks, y_val_tracks), class_weight=class_weights) 

    y_pred = classifier.predict(x_test_tracks)

    num_classes = 2
    threshold = 0.5
    y_pred_classes = np.argmax(y_pred, axis=1)

    # Calculate confusion matrix
    cm = confusion_matrix(y_test
# Epoch 45/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 890us/step - accuracy: 0.5826 - loss: 0.6198 - val_accuracy: 0.5000 - val_loss: 0.6267
# Epoch 46/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 948us/step - accuracy: 0.6006 - loss: 0.5879 - val_accuracy: 0.5362 - val_loss: 0.6273
# Epoch 47/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 968us/step - accuracy: 0.6037 - loss: 0.6162 - val_accuracy: 0.5725 - val_loss: 0.6012
# Epoch 48/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6333 - loss: 0.5966 - val_accuracy: 0.6087 - val_loss: 0.5749
# Epoch 49/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 840us/step - accuracy: 0.6208 - loss: 0.6112 - val_accuracy: 0.6159 - val_loss: 0.5718
# Epoch 50/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 878us/step - accuracy: 0.6111 - loss: 0.6157 - val_accuracy: 0.5725 - val_loss: 0.6048
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# [[0.53153153 0.46846847]
#  [0.25       0.75      ]]

# %%
from tensorflow.keras import layers, Sequential
import tensorflow as tf
from sklearn.utils.class_weight import compute_class_weight

conf_matrix_tabular = np.zeros((3, 2, 2)) 

for seed in [42, 43, 44]:

    class_weights = compute_class_weight('balanced', classes=np.unique(train_labels.flatten()), y=train_labels.flatten())
    class_weights = dict(enumerate(class_weights))

    tf.keras.utils.set_random_seed(seed)
    np.random.seed(seed)

    classifier = complex_mlp_classifier(latent_dim=train_tracks_features[:,:].shape[1]) #[:, [3, 8]] 
    #classifier = simple_mlp_classifier(latent_dim=time_norm_train_track[:,frame,:].shape[1])

    # Train the classifier
    classifier.compile(loss='sparse_categorical_crossentropy', optimizer= tf.keras.optimizers.Adam(learning_rate=0.001), metrics=['accuracy'])
    classifier.summary()

    x_val_tracks, x_test_tracks, y_val_tracks, y_test_tracks = train_test_split(test_tracks_features[:,:], test_labels, test_size=0.5, random_state=42) # 42 random state

    history = classifier.fit(train_tracks_features[:,:], train_labels, batch_size=32, epochs=100, validation_data=(x_val_tracks, y_val_tracks), class_weight=class_weights) 

    y_pred = classifier.predict(x_test_tracks)

    num_classes = 2
    threshold = 0.5
    y_pred_classes = np.argmax(y_pred, axis=1)

    # Calculate confusion matrix
    cm = confusion_matrix(y_test_tracks, y_pred_classes)

    class_sums = cm.sum(axis=1, keepdims=True)
    conf_matrix_normalized = cm / class_sums

    print(conf_matrix_normalized)

    conf_matrix_tabular[seed-42] = conf_matrix_normalized
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ batch_normalization_2           │ (None, 14)             │            56 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 32)             │           480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 8)              │           136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 8)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 2)              │            18 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,218 (4.76 KB)
#  Trainable params: 1,190 (4.65 KB)
#  Non-trainable params: 28 (112.00 B)
# Epoch 1/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7009 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 2/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 3/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 4/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 982us/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 5/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 961us/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 6/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 7/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 988us/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 8/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 893us/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 9/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 872us/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 10/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 806us/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 11/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 837us/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 12/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 864us/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 13/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 873us/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 14/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 838us/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 15/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 822us/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 16/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 835us/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 17/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 854us/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 18/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 901us/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 19/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 844us/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 20/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 21/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 22/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 809us/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 23/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 919us/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 24/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 25/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 26/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 859us/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 27/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 953us/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 28/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 902us/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 29/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 919us/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 30/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 855us/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 31/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 810us/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 32/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 839us/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 33/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 890us/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 34/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 829us/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 35/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 878us/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 36/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 851us/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 37/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 892us/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 38/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 879us/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 39/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 957us/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 40/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 41/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 876us/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 42/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 43/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 853us/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 44/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 938us/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 45/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 793us/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 46/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 778us/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 47/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 849us/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 48/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 814us/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 49/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 829us/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 50/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 866us/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 51/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 963us/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 52/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 890us/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 53/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 884us/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 54/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 55/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 856us/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 56/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 816us/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 57/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 820us/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 58/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 840us/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 59/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 845us/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 60/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 941us/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 61/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 840us/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 62/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 828us/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 63/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 835us/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 64/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 840us/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 65/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 867us/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 66/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 838us/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 67/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 884us/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 68/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 823us/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 69/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 889us/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 70/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 858us/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 71/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 809us/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 72/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 832us/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 73/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 812us/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 74/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 817us/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 75/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 76/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 852us/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 77/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 874us/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 78/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 834us/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 79/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 80/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 889us/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 81/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 820us/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 82/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 844us/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 83/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 830us/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 84/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 868us/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 85/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 867us/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 86/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 881us/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 87/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 830us/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 88/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 804us/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 89/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 90/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 897us/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 91/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 806us/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 92/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 93/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 94/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 915us/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 95/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 883us/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 96/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 929us/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 97/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 818us/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 98/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 804us/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 99/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 825us/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 100/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 856us/step - accuracy: 0.8372 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# [[1. 0.]
#  [1. 0.]]
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ batch_normalization_3           │ (None, 14)             │            56 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 32)             │           480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ (None, 8)              │           136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 8)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_15 (Dense)                │ (None, 2)              │            18 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,218 (4.76 KB)
#  Trainable params: 1,190 (4.65 KB)
#  Non-trainable params: 28 (112.00 B)
# Epoch 1/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5670 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 2/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 3/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 4/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 5/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 6/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 854us/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 7/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 895us/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 8/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 865us/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 9/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 876us/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 10/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 891us/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 11/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 888us/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 12/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 13/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 955us/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 14/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 946us/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 15/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 897us/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 16/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 845us/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 17/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 818us/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 18/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 852us/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 19/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 813us/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 20/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 792us/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 21/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 838us/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 22/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 931us/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 23/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 802us/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 24/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 794us/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 25/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 797us/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 26/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 776us/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 27/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 812us/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 28/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 796us/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 29/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 760us/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 30/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 817us/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 31/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 835us/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 32/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 757us/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 33/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 793us/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 34/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 793us/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 35/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 764us/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 36/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 799us/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 37/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 789us/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 38/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 804us/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 39/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 772us/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 40/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 804us/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 41/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 42/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 773us/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 43/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 825us/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 44/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 778us/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 45/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 803us/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 46/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 847us/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 47/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 858us/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 48/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 837us/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 49/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 50/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 817us/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 51/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 862us/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 52/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 924us/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 53/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 54/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 55/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 908us/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 56/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 57/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 813us/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 58/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 846us/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 59/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 857us/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 60/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 932us/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 61/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 887us/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 62/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 908us/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 63/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 885us/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 64/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 65/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 66/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 67/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 837us/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 68/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 829us/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 69/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 857us/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 70/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 871us/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 71/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 898us/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 72/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 867us/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 73/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 74/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 898us/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 75/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 842us/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 76/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 871us/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 77/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 833us/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 78/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 829us/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 79/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 828us/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 80/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 845us/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 81/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 819us/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 82/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 829us/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 83/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 859us/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 84/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 832us/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 85/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 876us/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 86/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 855us/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 87/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 893us/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 88/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 840us/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 89/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 90/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 880us/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 91/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 904us/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 92/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 865us/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 93/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 962us/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 94/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 888us/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 95/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 856us/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 96/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 849us/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 97/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 828us/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 98/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 864us/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 99/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 839us/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 100/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step - accuracy: 0.8459 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# [[1. 0.]
#  [1. 0.]]
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ batch_normalization_4           │ (None, 14)             │            56 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_16 (Dense)                │ (None, 32)             │           480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_12 (Dropout)            │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_17 (Dense)                │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_13 (Dropout)            │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_18 (Dense)                │ (None, 8)              │           136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_14 (Dropout)            │ (None, 8)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_19 (Dense)                │ (None, 2)              │            18 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,218 (4.76 KB)
#  Trainable params: 1,190 (4.65 KB)
#  Non-trainable params: 28 (112.00 B)
# Epoch 1/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7421 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 2/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 3/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 973us/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 4/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 804us/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 5/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 6/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 813us/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 7/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 833us/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 8/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 832us/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 9/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 10/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 880us/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 11/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 833us/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 12/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 874us/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 13/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 810us/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 14/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 828us/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 15/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 804us/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 16/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 866us/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 17/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 803us/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 18/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 869us/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 19/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 820us/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 20/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 804us/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 21/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 801us/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 22/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 843us/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 23/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 860us/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 24/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 809us/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 25/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 784us/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 26/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 27/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 789us/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 28/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 811us/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 29/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 824us/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 30/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 801us/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 31/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 797us/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 32/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 793us/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 33/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 811us/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 34/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 35/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 828us/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 36/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 816us/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 37/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 810us/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 38/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 813us/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 39/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 841us/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 40/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 832us/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 41/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 794us/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 42/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 807us/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 43/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 806us/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 44/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 799us/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 45/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 46/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 857us/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 47/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 856us/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 48/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 49/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 963us/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 50/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 51/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 880us/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 52/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 53/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 819us/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 54/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 789us/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 55/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 814us/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 56/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 794us/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 57/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 802us/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 58/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 833us/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 59/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 777us/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 60/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 813us/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 61/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 62/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 812us/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 63/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 791us/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 64/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 772us/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 65/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 784us/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 66/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 788us/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 67/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 779us/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 68/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 785us/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 69/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 790us/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 70/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 798us/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 71/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 819us/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 72/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 809us/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 73/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 799us/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 74/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 822us/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 75/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 829us/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 76/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 802us/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 77/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 773us/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 78/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 804us/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 79/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 776us/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 80/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 828us/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 81/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 82/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 778us/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 83/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 84/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 803us/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 85/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 789us/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 86/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 773us/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 87/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 792us/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 88/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 780us/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 89/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 815us/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 90/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 797us/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 91/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 791us/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 92/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 813us/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 93/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 799us/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 94/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 822us/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 95/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 851us/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 96/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 837us/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 97/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 835us/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 98/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 792us/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 99/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 770us/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# Epoch 100/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 816us/step - accuracy: 0.8129 - loss: nan - val_accuracy: 0.8696 - val_loss: nan
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# [[1. 0.]
#  [1. 0.]]

# %%
tabular_seed42 = np.load("/Users/inescunha/Documents/GitHub/CellFate/results/data_labelling_study/cumulative_split_1.0/confusion_matrices_tabular.npy")
tabular_seed43 = np.load("/Users/inescunha/Documents/GitHub/CellFate/results/data_labelling_study/cumulative_split_seed43_1.0/confusion_matrices_tabular.npy")
tabular_seed44 = np.load("/Users/inescunha/Documents/GitHub/CellFate/results/data_labelling_study/cumulative_split_seed44_1.0/confusion_matrices_tabular.npy")
conf_matrix_tabular= np.stack([tabular_seed42, tabular_seed43, tabular_seed44], axis=0)

# %%
conf_matrix_tabular
# Out:
# array([[[[0.63963964, 0.36036036],
#          [0.32142857, 0.67857143]]],
#
#
#        [[[0.62162162, 0.37837838],
#          [0.25      , 0.75      ]]],
#
#
#        [[[0.53153153, 0.46846847],
#          [0.25      , 0.75      ]]]])

# %%
ai4cellfate_seed42 = np.load("/Users/inescunha/Documents/GitHub/CellFate/results/data_labelling_study/cumulative_split_1.0/confusion_matrices_cellfate.npy")
ai4cellfate_seed43 = np.load("/Users/inescunha/Documents/GitHub/CellFate/results/data_labelling_study/cumulative_split_seed43_1.0/confusion_matrices_cellfate.npy")
ai4cellfate_seed44 = np.load("/Users/inescunha/Documents/GitHub/CellFate/results/data_labelling_study/cumulative_split_seed44_1.0/confusion_matrices_cellfate.npy")
conf_matrix_ai4cellfate = np.stack([ai4cellfate_seed42, ai4cellfate_seed43, ai4cellfate_seed44], axis=0)

# %%
conf_matrix_ai4cellfate.shape
# Out:
# (3, 1, 2, 2)

# %%
# get precision and accuracy for both cases

precision_tabular = np.zeros((conf_matrix_tabular.shape[0]))
accuracy_tabular = np.zeros((conf_matrix_tabular.shape[0]))
false_positives_tabular = np.zeros((conf_matrix_tabular.shape[0]))
false_negatives_tabular = np.zeros((conf_matrix_tabular.shape[0]))

for seed in range(conf_matrix_tabular.shape[0]):
    conf_matrix = conf_matrix_tabular[seed][0]
    print(conf_matrix.shape)
    precision_tabular[seed] = conf_matrix[0,0] / (conf_matrix[0,0] + conf_matrix[1,0])
    accuracy_tabular[seed] = (conf_matrix[0,0] + conf_matrix[1,1]) / np.sum(conf_matrix)
    false_positives_tabular[seed] = conf_matrix[1,0] #/ np.sum(conf_matrix[1,:])
    false_negatives_tabular[seed] = conf_matrix[0,1] #/ np.sum(conf_matrix[0,:])
# Out:
# (2, 2)
# (2, 2)
# (2, 2)

# %%
# get precision and accuracy for both cases

precision_ai4cellfate = np.zeros((conf_matrix_ai4cellfate.shape[0]))
accuracy_ai4cellfate = np.zeros((conf_matrix_ai4cellfate.shape[0]))
false_positives_ai4cellfate= np.zeros((conf_matrix_ai4cellfate.shape[0]))
false_negatives_ai4cellfate = np.zeros((conf_matrix_ai4cellfate.shape[0]))

for seed in range(conf_matrix_ai4cellfate.shape[0]):
    conf_matrix = conf_matrix_ai4cellfate[seed][0]
    print(conf_matrix.shape)
    precision_ai4cellfate[seed] = conf_matrix[0,0] / (conf_matrix[0,0] + conf_matrix[1,0])
    accuracy_ai4cellfate[seed] = (conf_matrix[0,0] + conf_matrix[1,1]) / np.sum(conf_matrix)
    false_positives_ai4cellfate[seed] = conf_matrix[1,0] #/ np.sum(conf_matrix[1,:])
    false_negatives_ai4cellfate[seed] = conf_matrix[0,1] #/ np.sum(conf_matrix[0,:])
# Out:
# (2, 2)
# (2, 2)
# (2, 2)

# %%
precision_tabular, precision_ai4cellfate
# Out:
# (array([0.66555072, 0.71317829, 0.68011527]),
#  array([0.75424354, 0.69421488, 0.76163207]))

# %%
accuracy_tabular, accuracy_ai4cellfate
# Out:
# (array([0.65910553, 0.68581081, 0.64076577]),
#  array([0.72168597, 0.68146718, 0.73519949]))

# %%
means_precision = [precision_tabular.mean(), precision_ai4cellfate.mean()]
std_precision = [precision_tabular.std(), precision_ai4cellfate.std()]
means_accuracy = [accuracy_tabular.mean(), accuracy_ai4cellfate.mean()]
std_accuracy = [accuracy_tabular.std(), accuracy_ai4cellfate.std()]

# X positions for bars (closer together)
x = np.array([0, 0.8])  # Precision bars
x2 = x + 2.0  # Accuracy bars (closer spacing)

# Plot
fig, ax = plt.subplots(figsize=(6, 5))

# Define bar width
bar_width = 0.7

# Bar plots with error bars
ax.bar(x, means_precision, yerr=std_precision, capsize=6, color=["orange", "turquoise"], edgecolor='black', width=bar_width, label="Precision")
ax.bar(x2, means_accuracy, yerr=std_accuracy, capsize=6, color=["orange", "turquoise"], edgecolor='black', width=bar_width, label="Accuracy")

# X-axis labels centered
ax.set_xticks([0.4, 2.4])  
ax.set_xticklabels(["Precision", "Accuracy"], fontsize=16, fontname='Arial')

# Y-axis label
ax.set_ylabel("Score", fontsize=18, fontname='Arial')

# Y-axis ticks (bigger font)
ax.tick_params(axis='y', labelsize=18)

# Title
ax.set_title("Performance Comparison: Tabular vs AI4CellFate", fontsize=18, fontname='Arial')

# Legend (top right with correct colors)
legend_labels = ["Tabular Features", "Latent Features"]
legend_colors = ["orange", "turquoise"]
legend_patches = [plt.Rectangle((0,0),1,1, color=color, edgecolor='black') for color in legend_colors]
ax.legend(legend_patches, legend_labels, loc="upper right", fontsize=14)

# Set y-axis limit
ax.set_ylim(0.5, 0.8)

plt.xticks(fontsize=18, fontname="Arial")
plt.yticks(fontsize=18, fontname="Arial")

# Grid
ax.yaxis.grid(True, linestyle='--', alpha=0.5)

plt.tight_layout()
#plt.savefig("barplot_all_feat_comparison.eps", dpi=300, bbox_inches="tight")
plt.show()
# Out:
# /var/folders/ds/_m8m03r135b5r67hc6xgtxt00000gn/T/ipykernel_28877/2038778691.py:36: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   legend_patches = [plt.Rectangle((0,0),1,1, color=color, edgecolor='black') for color in legend_colors]

# %%
# Compute means and standard deviations
means_precision = [precision_tabular.mean(), precision_ai4cellfate.mean()]
std_precision = [precision_tabular.std(), precision_ai4cellfate.std()]
means_accuracy = [accuracy_tabular.mean(), accuracy_ai4cellfate.mean()]
std_accuracy = [accuracy_tabular.std(), accuracy_ai4cellfate.std()]

# X positions for bars (closer together)
x = np.array([0, 0.8])  # Precision bars
x2 = x + 2.0  # Accuracy bars (closer spacing)

# Plot
fig, ax = plt.subplots(figsize=(6, 5))

# Define bar width
bar_width = 0.7

# Bar plots with error bars
ax.bar(x, means_precision, yerr=std_precision, capsize=6, color=["orange", "turquoise"], edgecolor='black', width=bar_width, label="Precision")
ax.bar(x2, means_accuracy, yerr=std_accuracy, capsize=6, color=["orange", "turquoise"], edgecolor='black', width=bar_width, label="Accuracy")

# X-axis labels centered
ax.set_xticks([0.4, 2.4])  
ax.set_xticklabels(["Precision", "Accuracy"], fontsize=16, fontname='Arial')

# Y-axis label
ax.set_ylabel("Score", fontsize=18, fontname='Arial')

# Y-axis ticks (bigger font)
ax.tick_params(axis='y', labelsize=18)

# Title with extra spacing
ax.set_title("Performance Comparison: Tabular vs AI4CellFate", fontsize=20, fontname='Arial', pad=20)

# Legend (top right with correct colors)
legend_labels = ["Tabular Features", "Latent Features"]
legend_colors = ["orange", "turquoise"]
legend_patches = [plt.Rectangle((0,0),1,1, color=color, edgecolor='black') for color in legend_colors]
ax.legend(legend_patches, legend_labels, loc="upper right", fontsize=14)

# Set y-axis limit
ax.set_ylim(0.5, 0.8)

plt.xticks(fontsize=18, fontname="Arial")
plt.yticks(fontsize=18, fontname="Arial")

# Grid
ax.yaxis.grid(True, linestyle='--', alpha=0.5)

plt.tight_layout()
plt.savefig("barplot_all_feat_comparison.eps", dpi=300, bbox_inches="tight")
plt.show()
# Out:
# /var/folders/ds/_m8m03r135b5r67hc6xgtxt00000gn/T/ipykernel_28877/2293490691.py:37: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   legend_patches = [plt.Rectangle((0,0),1,1, color=color, edgecolor='black') for color in legend_colors]
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# ## And now with the exact same model between tabular features and latent features

# %%
from tensorflow.keras import layers, Sequential
import tensorflow as tf
from sklearn.utils.class_weight import compute_class_weight

conf_matrix_tabular_simple = np.zeros((3, 2, 2)) # 3 random states, 11 time points, 2x2 confusion matrix

for seed in [42, 43, 44]:

    class_weights = compute_class_weight('balanced', classes=np.unique(train_labels.flatten()), y=train_labels.flatten())
    class_weights = dict(enumerate(class_weights))

    tf.keras.utils.set_random_seed(seed)
    np.random.seed(seed)

    # using same model as we use for the latent features
    classifier = mlp_classifier(latent_dim=train_tracks_features[:,:].shape[1]) #[:, [3, 8]] 
    #classifier = simple_mlp_classifier(latent_dim=time_norm_train_track[:,frame,:].shape[1])

    # Train the classifier
    classifier.compile(loss='sparse_categorical_crossentropy', optimizer= tf.keras.optimizers.Adam(learning_rate=config['learning_rate']), metrics=['accuracy'])
    classifier.summary()

    x_val_tracks, x_test_tracks, y_val_tracks, y_test_tracks = train_test_split(test_tracks_features[:,:], test_labels, test_size=0.5, random_state=42) # 42 random state

    history = classifier.fit(train_tracks_features[:,:], train_labels, batch_size=config['batch_size'], epochs=config['epochs'], validation_data=(x_val_tracks, y_val_tracks), class_weight=class_weights) 

    y_pred = classifier.predict(x_test_tracks)

    num_classes = 2
    threshold = 0.5
    y_pred_classes = np.argmax(y_pred, axis=1)

    # Calculate confusion matrix
    cm = confusion_matrix(y_test_tracks, y_pred_classes)

    class_sums = cm.sum(axis=1, keepdims=True)
    conf_matrix_normalized = cm / class_sums

    print(conf_matrix_normalized)

    conf_matrix_tabular_simple[seed-42] = conf_matrix_normalized
# Out:
# Model: "sequential_89"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dropout_97 (Dropout)            │ (None, 13)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_101 (Dense)               │ (None, 2)              │            28 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 28 (112.00 B)
#  Trainable params: 28 (112.00 B)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6455 - loss: 310.4450 - val_accuracy: 0.8116 - val_loss: 23.1982
# Epoch 2/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 765us/step - accuracy: 0.6249 - loss: 232.7152 - val_accuracy: 0.2536 - val_loss: 67.3228
# Epoch 3/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 651us/step - accuracy: 0.5118 - loss: 233.5694 - val_accuracy: 0.3261 - val_loss: 37.6426
# Epoch 4/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 673us/step - accuracy: 0.5286 - loss: 232.6502 - val_accuracy: 0.3696 - val_loss: 30.9210
# Epoch 5/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 680us/step - accuracy: 0.4988 - loss: 253.1135 - val_accuracy: 0.3043 - val_loss: 36.3812
# Epoch 6/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 645us/step - accuracy: 0.5209 - loss: 168.1858 - val_accuracy: 0.3478 - val_loss: 32.5501
# Epoch 7/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 641us/step - accuracy: 0.5278 - loss: 168.5726 - val_accuracy: 0.5580 - val_loss: 18.8712
# Epoch 8/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 655us/step - accuracy: 0.5638 - loss: 184.6783 - val_accuracy: 0.3406 - val_loss: 30.3965
# Epoch 9/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 628us/step - accuracy: 0.5111 - loss: 156.6452 - val_accuracy: 0.3551 - val_loss: 28.8034
# Epoch 10/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 640us/step - accuracy: 0.5070 - loss: 144.8342 - val_accuracy: 0.4420 - val_loss: 24.0470
# Epoch 11/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 641us/step - accuracy: 0.5711 - loss: 127.4837 - val_accuracy: 0.5072 - val_loss: 19.8210
# Epoch 12/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 613us/step - accuracy: 0.5232 - loss: 117.2407 - val_accuracy: 0.4493 - val_loss: 21.9564
# Epoch 13/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 622us/step - accuracy: 0.5075 - loss: 94.8967 - val_accuracy: 0.5000 - val_loss: 18.0219
# Epoch 14/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 633us/step - accuracy: 0.5503 - loss: 88.8356 - val_accuracy: 0.4275 - val_loss: 22.0639
# Epoch 15/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 641us/step - accuracy: 0.5125 - loss: 76.0681 - val_accuracy: 0.4275 - val_loss: 21.2579
# Epoch 16/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 609us/step - accuracy: 0.5130 - loss: 58.0831 - val_accuracy: 0.4493 - val_loss: 17.3493
# Epoch 17/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 685us/step - accuracy: 0.5518 - loss: 34.2993 - val_accuracy: 0.4058 - val_loss: 18.5016
# Epoch 18/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 653us/step - accuracy: 0.5241 - loss: 24.5208 - val_accuracy: 0.3116 - val_loss: 19.5331
# Epoch 19/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 637us/step - accuracy: 0.4757 - loss: 17.0871 - val_accuracy: 0.3696 - val_loss: 15.4155
# Epoch 20/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4705 - loss: 12.4488 - val_accuracy: 0.4275 - val_loss: 9.8744
# Epoch 21/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 619us/step - accuracy: 0.5178 - loss: 8.4442 - val_accuracy: 0.4783 - val_loss: 6.2930
# Epoch 22/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 762us/step - accuracy: 0.4827 - loss: 6.0088 - val_accuracy: 0.4855 - val_loss: 3.5472
# Epoch 23/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 655us/step - accuracy: 0.5483 - loss: 3.7345 - val_accuracy: 0.1449 - val_loss: 5.4087
# Epoch 24/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 640us/step - accuracy: 0
50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 611us/step - accuracy: 0.5412 - loss: 10.3185 - val_accuracy: 0.4638 - val_loss: 6.1166
# Epoch 31/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 614us/step - accuracy: 0.4943 - loss: 7.3845 - val_accuracy: 0.6449 - val_loss: 2.1905
# Epoch 32/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 591us/step - accuracy: 0.5154 - loss: 4.7224 - val_accuracy: 0.8043 - val_loss: 1.1811
# Epoch 33/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 591us/step - accuracy: 0.5369 - loss: 2.8747 - val_accuracy: 0.7029 - val_loss: 0.5930
# Epoch 34/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 580us/step - accuracy: 0.5197 - loss: 1.9235 - val_accuracy: 0.1304 - val_loss: 4.5804
# Epoch 35/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 586us/step - accuracy: 0.4989 - loss: 1.9051 - val_accuracy: 0.6377 - val_loss: 0.6349
# Epoch 36/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 590us/step - accuracy: 0.4830 - loss: 1.4989 - val_accuracy: 0.8623 - val_loss: 0.4455
# Epoch 37/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 613us/step - accuracy: 0.5130 - loss: 1.4356 - val_accuracy: 0.1304 - val_loss: 1.5266
# Epoch 38/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4959 - loss: 1.1336 - val_accuracy: 0.1377 - val_loss: 1.5738
# Epoch 39/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 588us/step - accuracy: 0.5369 - loss: 0.9623 - val_accuracy: 0.1304 - val_loss: 2.2293
# Epoch 40/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 589us/step - accuracy: 0.5437 - loss: 1.1188 - val_accuracy: 0.8478 - val_loss: 0.4823
# Epoch 41/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 601us/step - accuracy: 0.5462 - loss: 1.0906 - val_accuracy: 0.5725 - val_loss: 0.6903
# Epoch 42/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 594us/step - accuracy: 0.4972 - loss: 1.2963 - val_accuracy: 0.1304 - val_loss: 1.1725
# Epoch 43/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 674us/step - accuracy: 0.4991 - loss: 1.0905 - val_accuracy: 0.8261 - val_loss: 0.5264
# Epoch 44/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 618us/step - accuracy: 0.5395 - loss: 0.9619 - val_accuracy: 0.2174 - val_loss: 0.9024
# Epoch 45/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 936us/step - accuracy: 0.5859 - loss: 0.8346 - val_accuracy: 0.6449 - val_loss: 0.6372
# Epoch 46/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 893us/step - accuracy: 0.5540 - loss: 0.8530 - val_accuracy: 0.1304 - val_loss: 2.4963
# Epoch 47/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 780us/step - accuracy: 0.5263 - loss: 1.1380 - val_accuracy: 0.1667 - val_loss: 0.9915
# Epoch 48/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 626us/step - accuracy: 0.5346 - loss: 1.0559 - val_accuracy: 0.2319 - val_loss: 0.9867
# Epoch 49/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 628us/step - accuracy: 0.5611 - loss: 0.8376 - val_accuracy: 0.3333 - val_loss: 0.7637
# Epoch 50/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 601us/step - accuracy: 0.5656 - loss: 0.9144 - val_accuracy: 0.2609 - val_loss: 0.8447
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# [[0.22522523 0.77477477]
#  [0.         1.        ]]

# %%
# get precision and accuracy for both cases

precision_tabular_simple = np.zeros((conf_matrix_tabular_simple.shape[0]))
accuracy_tabular_simple = np.zeros((conf_matrix_tabular_simple.shape[0]))
false_positives_tabular_simple = np.zeros((conf_matrix_tabular_simple.shape[0]))
false_negatives_tabular_simple = np.zeros((conf_matrix_tabular_simple.shape[0]))

for seed in range(conf_matrix_tabular_simple.shape[0]):
    conf_matrix = conf_matrix_tabular_simple[seed]
    print(conf_matrix.shape)
    precision_tabular_simple [seed] = conf_matrix[0,0] / (conf_matrix[0,0] + conf_matrix[1,0])
    accuracy_tabular_simple [seed] = (conf_matrix[0,0] + conf_matrix[1,1]) / np.sum(conf_matrix)
    false_positives_tabular_simple [seed] = conf_matrix[1,0] #/ np.sum(conf_matrix[1,:])
    false_negatives_tabular_simple [seed] = conf_matrix[0,1] #/ np.sum(conf_matrix[0,:])
# Out:
# (2, 2)
# (2, 2)
# (2, 2)

# %%
accuracy_tabular_simple
# Out:
# array([0.5       , 0.53539254, 0.61261261])
